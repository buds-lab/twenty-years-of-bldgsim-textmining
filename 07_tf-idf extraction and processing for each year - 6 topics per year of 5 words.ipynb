# %% [markdown]
# # Cycle through each year and extract the major topics

# %%
import os
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
import operator
from sklearn.externals import joblib
from sklearn import decomposition

# %%
# %matplotlib inline

# %%
total_bldgsim = pd.read_pickle("/Users/nus/twenty-years-of-bldgsim-textmining/total_email_data.pkl")

# %%
total_bldgsim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20029 entries, 1999-03-04 08:26:46 to 2018-11-08 18:42:22
# Data columns (total 4 columns):
# From        20029 non-null object
# DateTime    20029 non-null datetime64[ns]
# Subject     20029 non-null object
# Body        20028 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 782.4+ KB

# %% [markdown]
# # Loop through each year and calculate the tf-idf and the topics for each year

# %%
def rank_terms( A, terms ):
    # get the sums over each column
    sums = A.sum(axis=0)
    # map weights to the terms
    weights = {}
    for col, term in enumerate(terms):
        weights[term] = sums[0,col]
    # rank the terms by their weight over all documents
    return sorted(weights.items(), key=operator.itemgetter(1), reverse=True)

# %%
def get_descriptor( terms, H, topic_index, top ):
    # reverse sort the values to sort the indices
    top_indices = np.argsort( H[topic_index,:] )[::-1]
    # now get the terms corresponding to the top-ranked indices
    top_terms = []
    for term_index in top_indices[0:top]:
        top_terms.append( terms[term_index] )
    top_terms = [item for item in top_terms if not item.isdigit()]
    return top_terms

# %%
k = 6

# %% [markdown]
# # Run through each year, get the top 10 topics and their top 10 words
#
# Put them in a dataframe with the year

# %%
all_topics = []
condensed_topics = []

# %%
for year in total_bldgsim.index.year.unique():
    bldg_sim_peryear = total_bldgsim[total_bldgsim.index.year == year]
    out_array = np.array(bldg_sim_peryear.fillna("x").Body)
    custom_stop_words = []
    with open( "/Users/nus/twenty-years-of-bldgsim-textmining/stopwords_annual_analysis_3.txt", "r" ) as fin:
        for line in fin.readlines():
            custom_stop_words.append( line.strip() )
    print(year)
    
    # use a custom stopwords list, set the minimum term-document frequency to 20
    vectorizer = CountVectorizer(stop_words = custom_stop_words, min_df = 20, encoding='latin-1')
    A = vectorizer.fit_transform(out_array)
    print( "Created %d X %d document-term matrix" % (A.shape[0], A.shape[1]) )
    
    # extract the resulting vocabulary
    terms = vectorizer.get_feature_names()
    print("Vocabulary has %d distinct terms" % len(terms))
    
    # we can pass in the same preprocessing parameters
    vectorizer = TfidfVectorizer(stop_words=custom_stop_words, min_df = 20, encoding='latin-1')
    A = vectorizer.fit_transform(out_array)
    print("Created %d X %d TF-IDF-normalized document-term matrix" % (A.shape[0], A.shape[1]) )
    
    joblib.dump((A,terms), "/Users/nus/twenty-years-of-bldgsim-textmining/emails-raw"+str(year)+".pkl") 
    
    (A,terms) = joblib.load( "/Users/nus/twenty-years-of-bldgsim-textmining/emails-raw"+str(year)+".pkl" )
    print( "Loaded %d X %d document-term matrix" % (A.shape[0], A.shape[1]) )
    
    model = decomposition.NMF( init="nndsvd", n_components=k ) 
    # apply the model and extract the two factor matrices
    W = model.fit_transform( A )
    H = model.components_
    
    descriptors = []
    condensed = []
    for topic_index in range(k):
        descriptors.append( get_descriptor( terms, H, topic_index, 5) )
        str_descriptor = ", ".join( descriptors[topic_index] )
        condensed.append(str_descriptor)
        print("Topic %02d: %s" % ( topic_index+1, str_descriptor ) )
    condensed_topics.append(condensed)
    
    descriptors_df = pd.DataFrame(descriptors).T
    descriptors_df['year'] = year
    all_topics.append(descriptors_df)
# Out:
# 1999
# Created 152 X 42 document-term matrix
# Vocabulary has 42 distinct terms
# Created 152 X 42 TF-IDF-normalized document-term matrix
# Loaded 152 X 42 document-term matrix
# Topic 01: doe, 1e, user, version, software
# Topic 02: research, ashrae, information, looking, bill
# Topic 03: jason, administrator, consultant, analytics
# Topic 04: number, jun, bill, see, large
# Topic 05: systems, software, better, source, available
# Topic 06: thermal, program, hourly, interested, web
# 2000
# Created 234 X 131 document-term matrix
# Vocabulary has 131 distinct terms
# Created 234 X 131 TF-IDF-normalized document-term matrix
# Loaded 234 X 131 document-term matrix
# Topic 01: doe, doe2, energyplus, powerdoe, program
# Topic 02: weather, hourly, john, website, find
# Topic 03: heat, water, air, temperature
# Topic 04: software, development, effort, university, available
# Topic 05: ashrae, research, systems, projects, engineer
# Topic 06: public, private, open, source, software
# 2001
# Created 211 X 77 document-term matrix
# Vocabulary has 77 distinct terms
# Created 211 X 77 TF-IDF-normalized document-term matrix
# Loaded 211 X 77 document-term matrix
# Topic 01: jason, problem, today, gpc18, analytics
# Topic 02: weather, doe, looking, street, group
# Topic 03: trnsys, engineering, university, software
# Topic 04: doe2, heat, 1e, temperature
# Topic 05: research, people, ashrae, corp, vice
# Topic 06: load, loads, doe, office, equipment
# 2002
# Created 247 X 137 document-term matrix
# Vocabulary has 137 distinct terms
# Created 247 X 137 TF-IDF-normalized document-term matrix
# Loaded 247 X 137 document-term matrix
# Topic 01: air, systems, control, floor, cooling
# Topic 02: jason, il, analytics, busse, highway
# Topic 03: powerdoe, dmiinc, ma, dmi, savings
# Topic 04: energyplus, available, software, information
# Topic 05: doe, 1e, control, modeling, case
# Topic 06: weather, sources, location, architecture, doe2
# 2003
# Created 541 X 622 document-term matrix
# Vocabulary has 622 distinct terms
# Created 541 X 622 TF-IDF-normalized document-term matrix
# Loaded 541 X 622 document-term matrix
# Topic 01: doe, equest, chiller, doe2, 1e
# Topic 02: mass, thermal, air, cooling, heat
# Topic 03: tamu, esl, jeff, haberl, texas
# Topic 04: yahoo, weather, actual, equest
# Topic 05: software, architects, tools, getting, architect
# Topic 06: ashrae, leed, modeling, method, standard
# 2004
# Created 621 X 801 document-term matrix
# Vocabulary has 801 distinct terms
# Created 621 X 801 TF-IDF-normalized document-term matrix
# Loaded 621 X 801 document-term matrix
# Topic 01: air, cooling, equest, vav, water
# Topic 02: radiant, heating, systems, temperature, research
# Topic 03: yahoo, equest, gerald, daylight, pde
# Topic 04: weather, tmy2, energyplus, program
# Topic 05: wall, window, lighting, glass, fenestration
# Topic 06: vikram, jason, forum, sami, web
# 2005
# Created 812 X 991 document-term matrix
# Vocabulary has 991 distinct terms
# Created 812 X 991 TF-IDF-normalized document-term matrix
# Loaded 812 X 991 document-term matrix
# Topic 01: equest, glumac, window, construction, vikram
# Topic 02: bb, jeff, haberl, tamu, texas
# Topic 03: yahoo, spam, gerald, tired, protection
# Topic 04: energyplus, engineering, green, software, information
# Topic 05: heat, water, recovery, exhaust, pump
# Topic 06: floor, thermal, temperature, south, air
# 2006
# Created 1022 X 1153 document-term matrix
# Vocabulary has 1153 distinct terms
# Created 1022 X 1153 TF-IDF-normalized document-term matrix
# Loaded 1022 X 1153 document-term matrix
# Topic 01: air, cooling, heat, water, temperature
# Topic 02: energyplus, doe, weather, software, doe2
# Topic 03: yahoo, spam, tired, protection, best
# Topic 04: natural, ventilation, ramana, koti, appendix
# Topic 05: equest, kendra, tupper, vikram, sami
# Topic 06: pv, bb, jeff, ibpsa, bipv
# 2007
# Created 2217 X 2707 document-term matrix
# Vocabulary has 2707 distinct terms
# Created 2217 X 2707 TF-IDF-normalized document-term matrix
# Loaded 2217 X 2707 document-term matrix
# Topic 01: loop, heat, pump, water, cooling
# Topic 02: software, developing, modeling, studioma, rosiers
# Topic 03: baseline, leed, orientation, existing
# Topic 04: elevator, vikram, elevators, sami, direct
# Topic 05: bb, jeff, haberl, tamu, texas
# Topic 06: nexant, unmet, john, equest, hours
# 2008
# Created 2055 X 2351 document-term matrix
# Vocabulary has 2351 distinct terms
# Created 2055 X 2351 TF-IDF-normalized document-term matrix
# Loaded 2055 X 2351 document-term matrix
# Topic 01: equest, weather, floor, wizard, program
# Topic 02: air, heat, cooling, water, load
# Topic 03: baseline, leed, existing, appendix, ashrae
# Topic 04: pae, engineers, jpeg, image, bytes
# Topic 05: bnim, ramana, consultant, koti, elements
# Topic 06: uk, paul, zed, cfd, carey
# 2009
# Created 1652 X 2706 document-term matrix
# Vocabulary has 2706 distinct terms
# Created 1652 X 2706 TF-IDF-normalized document-term matrix
# Loaded 1652 X 2706 document-term matrix
# Topic 01: yahoo, loads, cooling, roof, load
# Topic 02: unmet, hours, rosenberg, jim, michael
# Topic 03: fan, power, supply, exhaust, kw
# Topic 04: air, leed, baseline, ashrae, leakage
# Topic 05: hay, cost, leed, paul
# Topic 06: ies, energyplus, cfd, software, equest
# 2010
# Created 1899 X 2557 document-term matrix
# Vocabulary has 2557 distinct terms
# Created 1899 X 2557 TF-IDF-normalized document-term matrix
# Loaded 1899 X 2557 document-term matrix
# Topic 01: baseline, cooling, proposed, air, heating
# Topic 02: modeling, leed, ibpsa, conference, ashrae
# Topic 03: john, eurek, equest, nwo, voodoo
# Topic 04: whiteboxtechnologies, weather, doe, source, joe
# Topic 05: perkinswill, vikram, sami, addressee, chi01exmb
# Topic 06: window, nick, frame, smithboucher, glass
# 2011
# Created 1757 X 3064 document-term matrix
# Vocabulary has 3064 distinct terms
# Created 1757 X 3064 TF-IDF-normalized document-term matrix
# Loaded 1757 X 3064 document-term matrix
# Topic 01: baseline, air, fan, proposed, ventilation
# Topic 02: sheffer, leed, cost, marcus, hours
# Topic 03: 3d, font, span, style, div
# Topic 04: doe, haberl, weather, comfort, energyplus
# Topic 05: nick, smithboucher, leed, jpeg, caton
# Topic 06: epsteinglobal, ce, et, epstein, martin
# 2012
# Created 1228 X 2062 document-term matrix
# Vocabulary has 2062 distinct terms
# Created 1228 X 2062 TF-IDF-normalized document-term matrix
# Loaded 1228 X 2062 document-term matrix
# Topic 01: weather, energyplus_support, yahoo, groups, energyplus
# Topic 02: heat, cooling, heating, baseline, water
# Topic 03: alex, wichert, robert, mark, jon
# Topic 04: modeling, ibpsa, leed, conference, meeting
# Topic 05: bre, uk, wales, registered, england
# Topic 06: cleantech, analytics, cleantechanalytics, sheelam, khare
# 2013
# Created 2262 X 3703 document-term matrix
# Vocabulary has 3703 distinct terms
# Created 2262 X 3703 TF-IDF-normalized document-term matrix
# Loaded 2262 X 3703 document-term matrix
# Topic 01: ibpsa, energyplus, iesve, modeling, performance
# Topic 02: weather, whiteboxtechnologies, joe, binned, huang
# Topic 03: fan, wichert, seer, robert, power
# Topic 04: residential, floor, dormitory, floors, roof
# Topic 05: thumb, loads, christian, cooling, rules
# Topic 06: baseline, proposed, air, ventilation, outdoor
# 2014
# Created 1162 X 1972 document-term matrix
# Vocabulary has 1972 distinct terms
# Created 1162 X 1972 TF-IDF-normalized document-term matrix
# Loaded 1162 X 1972 document-term matrix
# Topic 01: openstudio, performance, modeling, ibpsa, training
# Topic 02: plug, loads, aeieng, chris, eac1
# Topic 03: whiteboxtechnologies, weather, joe, radiation, low
# Topic 04: jacobs, ventilation, jim, casework, baseline
# Topic 05: fan, curve, vav, reset, archenergy
# Topic 06: genopt, daysim, command, batch, bat
# 2015
# Created 846 X 2116 document-term matrix
# Vocabulary has 2116 distinct terms
# Created 846 X 2116 TF-IDF-normalized document-term matrix
# Loaded 846 X 2116 document-term matrix
# Topic 01: actual, app, models, jacob, appendix
# Topic 02: designbuilder, training, days, energyplus, openstudio
# Topic 03: julien, fan, lighting, gouv, dutel
# Topic 04: weather, whiteboxtechnologies, joe, utility, bills
# Topic 05: certification, experience, technical, leed, usgbc
# Topic 06: ibpsa, usa, news, newsletter, subscribe
# 2016
# Created 420 X 636 document-term matrix
# Vocabulary has 636 distinct terms
# Created 420 X 636 TF-IDF-normalized document-term matrix
# Loaded 420 X 636 document-term matrix
# Topic 01: performance, experience, webinar, research, leed
# Topic 02: openstudio, mc_cid, mc_eid, uniqid, psdconsulting
# Topic 03: ibpsa, usa, conference, news
# Topic 04: weather, whiteboxtechnologies, joe, climate, epw
# Topic 05: energyplus, workshop, openstudio, designbuilder, training
# Topic 06: jones, jim, water, thermal, intended
# 2017
# Created 406 X 490 document-term matrix
# Vocabulary has 490 distinct terms
# Created 406 X 490 TF-IDF-normalized document-term matrix
# Loaded 406 X 490 document-term matrix
# Topic 01: cgi, 40gmail, successfully, tresidder, entitled
# Topic 02: network, gototraining, attendee, performance, register
# Topic 03: jim, buildingperformanceteam, dirkes, leed, linkedin
# Topic 04: ibpsa, usa, buildingsimulation2017, news, conference
# Topic 05: energyplus, openstudio, workshop, bigladdersoftware, training
# Topic 06: weather, joe, whiteboxtechnologies, doe, solar
# 2018
# Created 285 X 413 document-term matrix
# Vocabulary has 413 distinct terms
# Created 285 X 413 TF-IDF-normalized document-term matrix
# Loaded 285 X 413 document-term matrix
# Topic 01: ibpsa, usa, news, conference, uniqid
# Topic 02: energyplus, openstudio, bigladdersoftware, workshop, training
# Topic 03: weather, wind, joe, rain, whiteboxtechnologies
# Topic 04: webinar, performance, tools, research, modeling
# Topic 05: tickets, eventbrite, tool, cost, optimization
# Topic 06: lighting, linkedin, leed, value, cgi

# %%
condensed_topics = pd.DataFrame(condensed_topics)

# %%
condensed_topics.to_excel("condensed_topics.xlsx")

# %%
all_topics_df = pd.concat(all_topics).reset_index(drop=True)

# %%
all_topics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 9 columns):
# 0       255 non-null object
# 1       255 non-null object
# 2       250 non-null object
# 3       253 non-null object
# 4       255 non-null object
# 5       252 non-null object
# 6       246 non-null object
# 7       247 non-null object
# year    260 non-null int64
# dtypes: int64(1), object(8)
# memory usage: 18.4+ KB

# %%
all_topics_df
# Out:
#                    0                  1                        2  \
# 0                doe             ashrae                    jason
# 1                 1e               bill            administrator
# 2               user               0400               consultant
# 3            version              large                analytics
# 4               0400         interested                     user
# 5              input               0500                    wrote
# 6               text                jun                     0600
# 7         experience            looking                    input
# 8               0700         references                     0500
# 9            project               text                     text
# 10              doe2            weather                     heat
# 11           hornets             hourly                    water
# 12            things            website                      air
# 13            people               0500              temperature
# 14              nest          different                  looking
# 15        energyplus               find                   source
# 16              code        appreciated                    phone
# 17              good             street                     0500
# 18            hirsch             source                     0600
# 19             tools              phone                analytics
# 20             jason            weather                   trnsys
# 21           problem            looking               university
# 22             today             source              engineering
# 23             gpc18              group                     0100
# 24         analytics            advance                      ext
# 25     administrator           engineer                      web
# 26                il             street                  project
# 27              park           question                     0500
# 28             ridge         university                    phone
# 29             busse               free                  looking
# ..               ...                ...                      ...
# 170       experience         openstudio                    ibpsa
# 171        technical             mc_eid                      usa
# 172    certification             mc_cid               conference
# 173           skills             uniqid                     news
# 174         research      psdconsulting               0af59bbb65
# 175             leed         utm_medium                     2016
# 176            green         utm_source                  meeting
# 177      engineering       utm_campaign               newsletter
# 178             team           training                    image
# 179          ability           2feepurl                   manage
# 180              cgi            network                      jim
# 181        tresidder       gototraining  buildingperformanceteam
# 182          40gmail           attendee                   dirkes
# 183     successfully           register                 linkedin
# 184         entitled        performance                    truth
# 185            leave               live                   mobile
# 186             info              42b11                     8653
# 187         messages            webinar                     bemp
# 188              6th          recording                   acacia
# 189  acknowledgement                cfd                    49504
# 190            ibpsa         energyplus                  weather
# 191              usa         openstudio                    solar
# 192             news  bigladdersoftware     whiteboxtechnologies
# 193           uniqid           workshop                      joe
# 194      performance           training                      box
# 195       0769126d70           controls                    white
# 196            board           advanced                  yjhuang
# 197           manage          workshops                    huang
# 198           member      practitioners             technologies
# 199         simbuild              index                  station
#
#                         3                  4                     5  \
# 0                  number            systems               thermal
# 1                     jun             better               program
# 2                     see          available            interested
# 3                   large             source                   web
# 4                    bill               text                 tools
# 5                  better              large               project
# 6                  hourly                web                 phone
# 7                      04              tools                  0500
# 8                   phone                 04                   see
# 9                     doe         interested               version
# 10               software             ashrae                public
# 11            development           research               private
# 12                 effort           projects                  open
# 13             university            systems                source
# 14              available           engineer              software
# 15            performance         commercial            investment
# 16           applications        information                hirsch
# 17                    pnl               0400                sector
# 18              equipment               site                  jeff
# 19               national                web               version
# 20                    doe             people                  doe2
# 21              available               corp                  heat
# 22            information               vice                    1e
# 23                   size                 st           temperature
# 24                   0500          president                  0400
# 25                 street                862                   ext
# 26                   0700                 ma                 suite
# 27                   find              voice              engineer
# 28                    web              suite                 phone
# 29               engineer                usa               program
# ..                    ...                ...                   ...
# 170               weather         energyplus                 jones
# 171  whiteboxtechnologies           workshop           information
# 172                   joe         openstudio              intended
# 173               climate      designbuilder           christopher
# 174                   epw           training               ontario
# 175                 huang         eventbrite               thermal
# 176                 white  bigladdersoftware                   eng
# 177             locations           software                 power
# 178                 suite             ladder         communication
# 179               yjhuang          workshops               toronto
# 180                 ibpsa         energyplus               weather
# 181                   usa         openstudio                   joe
# 182                  news           workshop  whiteboxtechnologies
# 183            newsletter  bigladdersoftware                   doe
# 184                latest           training                 huang
# 185               updates      designbuilder                   box
# 186             community           controls                 white
# 187                 issue             denver               yjhuang
# 188              training           software          technologies
# 189                manage          workshops              february
# 190              research            tickets              lighting
# 191               control         eventbrite              linkedin
# 192            experience               tool                 value
# 193          optimization               cost                  leed
# 194           engineering       optimization                   cgi
# 195               systems            company              listinfo
# 196                 tools            webinar                 wrote
# 197           performance           linkedin         designbuilder
# 198                 apply               free                annual
# 199              modeling             create                    pe
#
#                 6                        7                       8  \
# 0        software                   source                research
# 1      experience                   hourly                 project
# 2         looking                    wrote                    0700
# 3            0600                     good                   phone
# 4          better                     0700                    good
# 5           tools                       1e                     jun
# 6              04               interested                 program
# 7             web               references              experience
# 8         program                  looking               available
# 9         version                  program               analytics
# 10            doe                     john                powerdoe
# 11        program                  systems                    0500
# 12     energyplus                     free                modeling
# 13           user                  private             temperature
# 14    engineering                 modeling                    hvac
# 15          input                     high                   input
# 16        systems                     0800               including
# 17    information                     heat                 project
# 18        version                      see               interface
# 19      interface               interested                    find
# 20          loads                 research                software
# 21         office                   ashrae                 program
# 22          power              information                programs
# 23      equipment                    group                    size
# 24             05              engineering              experience
# 25           hvac                  systems                     jun
# 26          wrote               university               available
# 27         ashrae                    based                  people
# 28     references                     hvac                     web
# 29             il                 question                engineer
# ..            ...                      ...                     ...
# 170  gototraining                      jim                   water
# 171      attendee                   dirkes                 cooling
# 172      register  buildingperformanceteam                    heat
# 173       webinar                 linkedin                     air
# 174       network                      cgi                  source
# 175   performance                 listinfo                     hot
# 176          live                     8653                 version
# 177     organized                       ii                    cost
# 178   grasshopper                      ceo                   chris
# 179        series                     1631                electric
# 180           510                 research  buildingsimulation2017
# 181         chris              engineering                   ibpsa
# 182         solar               university                   image
# 183       glazing               experience              conference
# 184         wrote              environment            registration
# 185            uk               technology                 twitter
# 186         green                  systems                facebook
# 187         glass                institute                   click
# 188          best                    based                linkedin
# 189         range              information                     usa
# 190          wind                  webinar              conference
# 191          rain                 register                   users
# 192        driven              performance                modeling
# 193           joe                   denver                simbuild
# 194      stations                 attendee           presentations
# 195     different              gotowebinar                  ashrae
# 196         speed                    green             conferences
# 197         urban             presentation                 program
# 198            uk                  network             performance
# 199         field                   school                      3a
#
#                 9  year
# 0     information  1999
# 1      interested  1999
# 2         looking  1999
# 3            site  1999
# 4             web  1999
# 5            good  1999
# 6            bill  1999
# 7       available  1999
# 8           tools  1999
# 9           phone  1999
# 10           mark  2000
# 11           case  2000
# 12          group  2000
# 13           0600  2000
# 14     commercial  2000
# 15            jun  2000
# 16        program  2000
# 17             go  2000
# 18           find  2000
# 19     experience  2000
# 20           load  2001
# 21       question  2001
# 22        systems  2001
# 23           0500  2001
# 24           hvac  2001
# 25        program  2001
# 26         source  2001
# 27     interested  2001
# 28        project  2001
# 29    temperature  2001
# ..            ...   ...
# 170      standard  2016
# 171        ashrae  2016
# 172        review  2016
# 173        public  2016
# 174         jason  2016
# 175         chair  2016
# 176   residential  2016
# 177            ny  2016
# 178      appendix  2016
# 179  requirements  2016
# 180        ashrae  2017
# 181    conference  2017
# 182   performance  2017
# 183   conferences  2017
# 184          leed  2017
# 185      modeling  2017
# 186        review  2017
# 187      standard  2017
# 188     available  2017
# 189   residential  2017
# 190       heating  2018
# 191        source  2018
# 192       project  2018
# 193       thermal  2018
# 194       systems  2018
# 195           air  2018
# 196          case  2018
# 197        ashrae  2018
# 198   residential  2018
# 199       example  2018
#
# [200 rows x 11 columns]

# %%
all_topics_df_melted = all_topics_df.melt(id_vars='year')

# %%
all_topics_df_melted.head()
# Out:
#    year variable    value
# 0  1999        0      doe
# 1  1999        0       1e
# 2  1999        0     user
# 3  1999        0  version
# 4  1999        0     0400

# %%
all_topics_df_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
# year        2000 non-null int64
# variable    2000 non-null object
# value       2000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 46.9+ KB

# %%
wordfreq = all_topics_df_melted.value.value_counts()

# %%
wordfreq.head(40)
# Out:
# leed           24
# energyplus     20
# cooling        20
# ashrae         18
# heat           18
# weather        18
# equest         17
# performance    16
# software       16
# air            15
# baseline       15
# doe            15
# modeling       15
# experience     15
# source         14
# program        14
# fan            14
# ibpsa          14
# available      13
# water          13
# engineering    13
# information    12
# web            12
# systems        12
# heating        12
# usa            12
# thermal        12
# temperature    11
# doe2           11
# 0500           11
# training       10
# conference     10
# university     10
# joe            10
# load           10
# yahoo           9
# jeff            9
# research        9
# version         9
# interested      8
# Name: value, dtype: int64

# %%
wordfreq
# Out:
# leed                   24
# energyplus             20
# cooling                20
# ashrae                 18
# heat                   18
# weather                18
# equest                 17
# performance            16
# software               16
# air                    15
# baseline               15
# doe                    15
# modeling               15
# experience             15
# source                 14
# program                14
# fan                    14
# ibpsa                  14
# available              13
# water                  13
# engineering            13
# information            12
# web                    12
# systems                12
# heating                12
# usa                    12
# thermal                12
# temperature            11
# doe2                   11
# 0500                   11
#                        ..
# qm                      1
# espr                    1
# recommendations         1
# dcmit_esiyok            1
# qc                      1
# lexington               1
# bat                     1
# eskewdumezripple        1
# prosoco                 1
# click                   1
# 01                      1
# cop                     1
# 361                     1
# javed                   1
# energyplus_support      1
# vrf                     1
# job                     1
# efficiency              1
# 0af59bbb65              1
# exam                    1
# jta                     1
# sheffer                 1
# volume                  1
# outside                 1
# mud                     1
# dormitory               1
# fenestration            1
# naturalintelligence     1
# 07                      1
# natural                 1
# Name: value, Length: 831, dtype: int64

# %%
wordfreq.to_csv("word_frequency.csv")
