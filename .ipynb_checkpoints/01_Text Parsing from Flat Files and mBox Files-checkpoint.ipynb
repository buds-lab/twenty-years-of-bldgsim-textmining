# %% [markdown]
# # Extract Data from all the 1999-2015 flat files found in the online archive
#
# Instead, we will use the `.mbox` files sent by Jason later

# %%
import os
from dateutil import parser
import pandas as pd
import numpy as np
import re
import email

# %%
path = '/Users/nus/twenty-years-of-bldgsim-textmining/datafiles/'
#file = open('/Users/millerc/Dropbox/CODE/BLDG-SIM Analysis/2012-December.txt')
filelist = os.listdir(path)
os.chdir(path)

# %%
filelist
# Out:
# ['2004-April.txt',
#  '2010-January.txt',
#  '2003-March.txt',
#  '2003-May.txt',
#  '2015-February.txt',
#  '2013-May.txt',
#  '2003-August.txt',
#  '2012-February.txt',
#  '2005-September.txt',
#  '2008-October.txt',
#  '2012-September.txt',
#  '2010-April.txt',
#  '2010-July.txt',
#  '2007-February.txt',
#  '2011-July.txt',
#  '2014-October.txt',
#  '2000-February.txt',
#  '1999-September.txt',
#  '1999-October.txt',
#  '2001-September.txt',
#  '2009-April.txt',
#  '2001-October.txt',
#  '2010-June.txt',
#  '2011-June.txt',
#  '2005-January.txt',
#  '2012-August.txt',
#  '1999-December.txt',
#  '2001-February.txt',
#  '2006-February.txt',
#  '2004-October.txt',
#  '1999-November.txt',
#  '.DS_Store',
#  '1999-March.txt',
#  '2013-February.txt',
#  '2002-April.txt',
#  '2005-March.txt',
#  '2000-January.txt',
#  '2014-February.txt',
#  '2011-March.txt',
#  '2007-July.txt',
#  '2006-July.txt',
#  '2012-May.txt',
#  '2002-May.txt',
#  '2011-September.txt',
#  '2006-August.txt',
#  '2006-September.txt',
#  '2015-January.txt',
#  '2009-January.txt',
#  '2008-March.txt',
#  '2002-September.txt',
#  '2011-October.txt',
#  '2007-June.txt',
#  '2006-June.txt',
#  '2007-November.txt',
#  '2012-October.txt',
#  '2000-November.txt',
#  '2011-April.txt',
#  '2009-May.txt',
#  '2005-April.txt',
#  '2002-March.txt',
#  '2008-September.txt',
#  '1999-April.txt',
#  '2001-August.txt',
#  '2012-November.txt',
#  '2000-July.txt',
#  '2001-July.txt',
#  '2006-December.txt',
#  '2001-December.txt',
#  '2008-April.txt',
#  '2010-August.txt',
#  '2003-January.txt',
#  '2000-May.txt',
#  '2010-May.txt',
#  '2014-December.txt',
#  '2013-December.txt',
#  '2000-June.txt',
#  '2001-June.txt',
#  '2007-October.txt',
#  '2006-January.txt',
#  '2013-November.txt',
#  '2014-November.txt',
#  '2015-August.txt',
#  '2011-May.txt',
#  '2001-May.txt',
#  '2001-November.txt',
#  '2002-October.txt',
#  '2010-March.txt',
#  '2009-August.txt',
#  '2006-November.txt',
#  '2003-April.txt',
#  '2004-March.txt',
#  '2012-December.txt',
#  '2008-May.txt',
#  '2000-December.txt',
#  '2007-December.txt',
#  '2004-August.txt',
#  '2013-January.txt',
#  '2009-March.txt',
#  '2008-January.txt',
#  '2010-October.txt',
#  '2011-November.txt',
#  '2006-April.txt',
#  '2001-March.txt',
#  '2014-January.txt',
#  '2004-November.txt',
#  '2004-June.txt',
#  '2015-March.txt',
#  '2012-April.txt',
#  '2005-June.txt',
#  '2003-November.txt',
#  '2007-August.txt',
#  '2001-January.txt',
#  '2010-December.txt',
#  '2008-February.txt',
#  '2005-October.txt',
#  '2004-May.txt',
#  '2014-May.txt',
#  '2005-December.txt',
#  '2004-July.txt',
#  '2005-July.txt',
#  '2002-December.txt',
#  '1999-July.txt',
#  '2000-April.txt',
#  '2007-March.txt',
#  '2013-March.txt',
#  '2002-November.txt',
#  '2014-April.txt',
#  '2002-August.txt',
#  '2005-November.txt',
#  '2004-January.txt',
#  '2013-June.txt',
#  '2012-June.txt',
#  '2009-September.txt',
#  '2010-November.txt',
#  '2000-October.txt',
#  '2015-May.txt',
#  '2005-May.txt',
#  '1999-June.txt',
#  '2003-December.txt',
#  '2004-December.txt',
#  '2013-July.txt',
#  '2012-July.txt',
#  '2013-August.txt',
#  '1999-May.txt',
#  '2011-January.txt',
#  '2011-December.txt',
#  '2009-February.txt',
#  '2009-October.txt',
#  '2004-February.txt',
#  '2012-January.txt',
#  '2003-February.txt',
#  '2014-August.txt',
#  '2014-June.txt',
#  '2014-March.txt',
#  '2015-June.txt',
#  '2013-April.txt',
#  '2007-May.txt',
#  '2007-April.txt',
#  '2000-March.txt',
#  '2008-August.txt',
#  '2009-December.txt',
#  '2011-February.txt',
#  '2014-September.txt',
#  '2003-September.txt',
#  '2003-October.txt',
#  '2005-August.txt',
#  '2007-September.txt',
#  '2014-July.txt',
#  '2010-September.txt',
#  '2015-July.txt',
#  '2007-January.txt',
#  '2008-November.txt',
#  '2012-March.txt',
#  '2015-April.txt',
#  '2000-September.txt',
#  '2006-October.txt',
#  '2008-December.txt',
#  '2010-February.txt',
#  '2001-April.txt',
#  '2006-March.txt',
#  '2013-September.txt',
#  '2004-September.txt',
#  '2009-July.txt',
#  '2008-July.txt',
#  '2002-February.txt',
#  '2003-June.txt',
#  '2002-June.txt',
#  '2002-January.txt',
#  '2000-August.txt',
#  '2005-February.txt',
#  '2011-August.txt',
#  '2009-November.txt',
#  '2013-October.txt',
#  '2006-May.txt',
#  '2009-June.txt',
#  '2008-June.txt',
#  '2003-July.txt',
#  '2002-July.txt',
#  '1999-August.txt']

# %%
DataList = []
BodyList = []

#Open all the files one at a time
for file in filelist:
    i=0
    openfile = open(file)
    linelist = [line for line in openfile.readlines()]
    linelistmax=len(linelist)

    #Iterate through each file and find the From:, Date:, and Subject: for each email
    body = []
    while i < linelistmax:
        
        try:
            if linelist[i][:5] == 'From:':
                if linelist[i+2][:8] == 'Subject:':              
                    WholeDate = parser.parse(linelist[i+1][6:]).replace(tzinfo=None)
                    Date = WholeDate.date()
#                    YearMonth = WholeDate.replace(day=0)
                    DataEntry = (linelist[i][5:], Date, WholeDate, linelist[i+2][19:])
                    DataList.append(DataEntry)
                    BodyList.append(" ".join(str(x) for x in body))
                    body = []
                else:
                    body.append(linelist[i-1])
            else:
                body.append(linelist[i-1])
        except ValueError:
            print 'Bad Date: '+linelist[i+1]
        i+=1
    #BodyList.append(body)
    print "Finished Loading "+file
BodyList.append(" ".join(str(x) for x in body))
# Out:
# Finished Loading 2004-April.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org, juliabeabout at yahoo.com
#
# Bad Date: To: <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: Bldg-Sim <bldg-sim at lists.onebuilding.org>
#
# Finished Loading 2010-January.txt
# Finished Loading 2003-March.txt
# Finished Loading 2003-May.txt
# Finished Loading 2015-February.txt
# Finished Loading 2013-May.txt
# Finished Loading 2003-August.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Finished Loading 2012-February.txt
# Finished Loading 2005-September.txt
# Bad Date: <MICHAEL.L.KINGSLEY at saic.com>
#
# Bad Date: 	<routhconsultingengineers at charter.net>
#
# Finished Loading 2008-October.txt
# Finished Loading 2012-September.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: 'Hopf, Johannes' , bldg-sim at lists.onebuilding.org
#
# Bad Date: To: 'Hopf, Johannes' , bldg-sim at lists.onebuilding.org
#
# Finished Loading 2010-April.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: "bldg-sim at lists.onebuilding.org" <Bldg-sim at lists.onebuilding.org>
#
# Finished Loading 2010-July.txt
# Finished Loading 2007-February.txt
# Finished Loading 2011-July.txt
# Finished Loading 2014-October.txt
# Finished Loading 2000-February.txt
# Bad Date: Date: Mon, 6 Sep 1999 13:37:50 GMT0BST
#
# Finished Loading 1999-September.txt
# Finished Loading 1999-October.txt
# Finished Loading 2001-September.txt
# Bad Date: Date: Mon, 6 Apr 2009 18:35:00 -0400 (GMT-04:00)
#
# Finished Loading 2009-April.txt
# Finished Loading 2001-October.txt
# Bad Date: To: <bldg-sim at lists.onebuilding.org>
#
# Finished Loading 2010-June.txt
# Finished Loading 2011-June.txt
# Finished Loading 2005-January.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: <bldg-sim at lists.onebuilding.org>
#
# Finished Loading 2012-August.txt
# Finished Loading 1999-December.txt
# Finished Loading 2001-February.txt
# Finished Loading 2006-February.txt
# Finished Loading 2004-October.txt
# Finished Loading 1999-November.txt
# Finished Loading .DS_Store
# Finished Loading 1999-March.txt
# Finished Loading 2013-February.txt
# Finished Loading 2002-April.txt
# Finished Loading 2005-March.txt
# Finished Loading 2000-January.txt
# Finished Loading 2014-February.txt
# Bad Date: Date: Tue, 29 Mar 2011 00:08:42 -0400 (GMT-04:00)
#
# Finished Loading 2011-March.txt
# Bad Date: Date sent:	Tue, 24 Jul 2007 00:13:29 -0000
#
# Bad Date: Date sent:	Tue, 24 Jul 2007 00:13:29 -0000
#
# Finished Loading 2007-July.txt
# Finished Loading 2006-July.txt
# Finished Loading 2012-May.txt
# Finished Loading 2002-May.txt
# Bad Date: Date: Tue, 6 Sep 2011 15:45:52 -0400 (GMT-04:00)
#
# Finished Loading 2011-September.txt
# Bad Date: Date: Thu, 31 Aug 2006 15:26:58 -0400 (GMT-04:00)
#
# Finished Loading 2006-August.txt
# Finished Loading 2006-September.txt
# Finished Loading 2015-January.txt
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Finished Loading 2009-January.txt
# Finished Loading 2008-March.txt
# Finished Loading 2002-September.txt
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Finished Loading 2011-October.txt
# Bad Date: Date: Wed, 13 Jun 2007 01:40:13 -0400 (GMT-04:00)
#
# Bad Date: Date: Wed, 13 Jun 2007 01:40:13 -0400 (GMT-04:00)
#
# Bad Date: Date: Wed, 13 Jun 2007 01:40:13 -0400 (GMT-04:00)
#
# Finished Loading 2007-June.txt
# Finished Loading 2006-June.txt
# Finished Loading 2007-November.txt
# Finished Loading 2012-October.txt
# Finished Loading 2000-November.txt
# Bad Date: To: bldg <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: bldg <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: bldg <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: bldg <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Finished Loading 2011-April.txt
# Bad Date:
#
# Bad Date:
#
# Bad Date:
#
# Finished Loading 2009-May.txt
# Finished Loading 2005-April.txt
# Finished Loading 2002-March.txt
# Finished Loading 2008-September.txt
# Finished Loading 1999-April.txt
# Finished Loading 2001-August.txt
# Finished Loading 2012-November.txt
# Finished Loading 2000-July.txt
# Finished Loading 2001-July.txt
# Finished Loading 2006-December.txt
# Finished Loading 2001-December.txt
# Finished Loading 2008-April.txt
# Finished Loading 2010-August.txt
# Finished Loading 2003-January.txt
# Finished Loading 2000-May.txt
# Finished Loading 2010-May.txt
# Finished Loading 2014-December.txt
# Finished Loading 2013-December.txt
# Bad Date: To: <BLDG-SIM at gard.com>
#
# Finished Loading 2000-June.txt
# Finished Loading 2001-June.txt
# Finished Loading 2007-October.txt
# Finished Loading 2006-January.txt
# Finished Loading 2013-November.txt
# Finished Loading 2014-November.txt
# Finished Loading 2015-August.txt
# Finished Loading 2011-May.txt
# Bad Date: To:             	"'bldg-sim at gard.com'" <bldg-sim at gard.com>
#
# Finished Loading 2001-May.txt
# Finished Loading 2001-November.txt
# Bad Date: To:             	"Jason Glazer" <JGlazer at gard.com>
#
# Finished Loading 2002-October.txt
# Finished Loading 2010-March.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: Date: Thu, 27 Aug 2009 15:25:45 -0400 (GMT-04:00)
#
# Finished Loading 2009-August.txt
# Finished Loading 2006-November.txt
# Finished Loading 2003-April.txt
# Finished Loading 2004-March.txt
# Bad Date: To: cj at enersave.ca; kinghochik at hotmail.com; bldg-sim at lists.onebuilding.org; equest-users at lists.onebuilding.org
#
# Finished Loading 2012-December.txt
# Finished Loading 2008-May.txt
# Finished Loading 2000-December.txt
# Bad Date: Date: Mon, 3 Dec 2007 06:51:11 -0500 (GMT-05:00)
#
# Finished Loading 2007-December.txt
# Finished Loading 2004-August.txt
# Finished Loading 2013-January.txt
# Finished Loading 2009-March.txt
# Finished Loading 2008-January.txt
# Bad Date: Date: Tue, 5 Oct 2010 11:42:47 -0400 (GMT-04:00)
#
# Bad Date: Date: Tue, 5 Oct 2010 22:36:01 -0400 (GMT-04:00)
#
# Bad Date: Date: Wed, 6 Oct 2010 15:06:53 -0400 (GMT-04:00)
#
# Bad Date: Date: Thu, 7 Oct 2010 12:01:06 -0400 (GMT-04:00)
#
# Finished Loading 2010-October.txt
# Finished Loading 2011-November.txt
# Finished Loading 2006-April.txt
# Finished Loading 2001-March.txt
# Finished Loading 2014-January.txt
# Finished Loading 2004-November.txt
# Finished Loading 2004-June.txt
# Finished Loading 2015-March.txt
# Finished Loading 2012-April.txt
# Finished Loading 2005-June.txt
# Finished Loading 2003-November.txt
# Bad Date: Date sent:	Tue, 24 Jul 2007 00:13:29 -0000
#
# Finished Loading 2007-August.txt
# Finished Loading 2001-January.txt
# Bad Date: To: ADahlstrom at in-posse.com<mailto:ADahlstrom at in-posse.com>; bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: ADahlstrom at in-posse.com<mailto:ADahlstrom at in-posse.com>; bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: ADahlstrom at in-posse.com; bldg-sim at lists.onebuilding.org
#
# Bad Date: To: <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: James Hansen <JHANSEN at ghtltd.com>, bldg-sim at lists.onebuilding.org
#
# Finished Loading 2010-December.txt
# Finished Loading 2008-February.txt
# Finished Loading 2005-October.txt
# Finished Loading 2004-May.txt
# Finished Loading 2014-May.txt
# Finished Loading 2005-December.txt
# Bad Date: Date: Thu, 22 Jul 2004 12:37:36 +0000 (Asia/Calcutta)
#
# Finished Loading 2004-July.txt
# Bad Date: Date: Tue, 5 Jul 2005 08:18:51 -0400 (GMT-04:00)
#
# Finished Loading 2005-July.txt
# Finished Loading 2002-December.txt
# Finished Loading 1999-July.txt
# Finished Loading 2000-April.txt
# Finished Loading 2007-March.txt
# Finished Loading 2013-March.txt
# Finished Loading 2002-November.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Finished Loading 2014-April.txt
# Finished Loading 2002-August.txt
# Finished Loading 2005-November.txt
# Finished Loading 2004-January.txt
# Finished Loading 2013-June.txt
# Bad Date: To: moon161 at gmail.com; equest-users at lists.onebuilding.org
# Bad Date: To: a2_azhari at hotmail.com; bldg-sim at lists.onebuilding.org
#
# Bad Date: To: a2_azhari at hotmail.com; bldg-sim at lists.onebuilding.org
#
# Bad Date: To: a2_azhari at hotmail.com<mailto:a2_azhari at hotmail.com>; bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org
ldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: maria.karpman at karpmanconsulting.net; jim at buildingperformanceteam.com; oconnor_dj at hotmail.com; rwattanasak at emoenergy.com; bldg-sim at lists.onebuilding.org
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: jim at buildingperformanceteam.com; oconnor_dj at hotmail.com; bldg-sim at lists.onebuilding.org
#
# Bad Date: To: jim at buildingperformanceteam.com<mailto:jim at buildingperformanceteam.com>; oconnor_dj at hotmail.com<mailto:oconnor_dj at hotmail.com>; bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: maria.karpman at karpmanconsulting.net; jim at buildingperformanceteam.com; oconnor_dj at hotmail.com; rwattanasak at emoenergy.com; bldg-sim at lists.onebuilding.org
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: "BLDGSIM" <bldg-sim at lists.onebuilding.org>
#
# Finished Loading 2013-April.txt
# Finished Loading 2007-May.txt
# Bad Date: Date: Fri, 13 Apr 2007 15:19:08 -0400 (GMT-04:00)
#
# Finished Loading 2007-April.txt
# Finished Loading 2000-March.txt
# Bad Date: Date: Fri, 8 Aug 2008 13:26:37 -0400 (GMT-04:00)
#
# Bad Date: Date: Tue, 26 Aug 2008 15:16:54 -0400 (GMT-04:00)
#
# Bad Date: Date: Tue, 26 Aug 2008 16:17:12 -0400 (GMT-04:00)
#
# Finished Loading 2008-August.txt
# Finished Loading 2009-December.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Finished Loading 2011-February.txt
# Finished Loading 2014-September.txt
# Finished Loading 2003-September.txt
# Finished Loading 2003-October.txt
# Finished Loading 2005-August.txt
# Finished Loading 2007-September.txt
# Bad Date: To: "bldg-sim at lists.onebuilding.org" <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: "bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: "bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: "bldg-sim at lists.onebuilding.org" <bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: "bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Bad Date: To: "bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>" <bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>>
#
# Finished Loading 2014-July.txt
# Bad Date: Date: Fri, 10 Sep 2010 13:41:18 -0400 (GMT-04:00)
#
# Bad Date: Date: Fri, 10 Sep 2010 18:09:45 -0400 (GMT-04:00)
#
# Finished Loading 2010-September.txt
# Bad Date: Date: Tue, 21 Jul 2015 12:03:18 -0400 (GMT-04:00)
#
# Finished Loading 2015-July.txt
# Finished Loading 2007-January.txt
# Bad Date:
#
# Bad Date:
#
# Bad Date: Date: Tue, 11 Nov 2008 09:59:40 -0500 (GMT-05:00)
#
# Bad Date: Date: Tue, 18 Nov 2008 13:08:38 -0500 (GMT-05:00)
#
# Finished Loading 2008-November.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org<mailto:bldg-sim at lists.onebuilding.org>
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Finished Loading 2012-March.txt
# Finished Loading 2015-April.txt
# Finished Loading 2000-September.txt
# Finished Loading 2006-October.txt
# Bad Date:
#
# Finished Loading 2008-December.txt
# Finished Loading 2010-February.txt
# Finished Loading 2001-April.txt
# Finished Loading 2006-March.txt
# Finished Loading 2013-September.txt
# Finished Loading 2004-September.txt
# Finished Loading 2009-July.txt
# Bad Date: <routhconsultingengineers at charter.net>
#
# Finished Loading 2008-July.txt
# Finished Loading 2002-February.txt
# Finished Loading 2003-June.txt
# Finished Loading 2002-June.txt
# Finished Loading 2002-January.txt
# Finished Loading 2000-August.txt
# Finished Loading 2005-February.txt
# Bad Date: Date: Fri, 26 Aug 2011 13:15:24 -0400 (GMT-04:00)
#
# Bad Date: Date: Fri, 26 Aug 2011 16:21:40 -0400 (GMT-04:00)
#
# Bad Date: Date: Wed, 31 Aug 2011 13:03:39 -0400 (GMT-04:00)
#
# Finished Loading 2011-August.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org
#
# Bad Date: To: <bldg-sim at lists.onebuilding.org>
# Finished Loading 2009-November.txt
# Finished Loading 2013-October.txt
# Finished Loading 2006-May.txt
# Bad Date: Date: Fri, 26 Jun 2009 15:00:49 -0400 (GMT-04:00)
#
# Finished Loading 2009-June.txt
# Bad Date: To: bldg-sim at lists.onebuilding.org; sbse at uidaho.edu
#
# Bad Date: To: bldg-sim at lists.onebuilding.org; sbse at uidaho.edu
#
# Finished Loading 2008-June.txt
# Finished Loading 2003-July.txt
# Finished Loading 2002-July.txt
# Finished Loading 1999-August.txt

# %%
len(BodyList)
# Out:
# 19592

# %%
body_df = pd.DataFrame({"Body":BodyList[1:]})

# %%
body_df.iloc[-1].Body.strip()
# Out:
# 'From: Mmullins at hecenergy.com (Mark Mullins)\n Date: Mon, 02 Aug 1999 18:03:42 -0400\n Subject: [BLDG-SIM] Fan-powered VAV systems in DOE-2\n Message-ID: <MDAEMON-F199908030958.AA581554MD63745@gard.com>\n \n To PowerDOE/DOE-2 users:\n Has anyone out there successfully modeled a DX fan-powered VAV system in doe-2.2 or doe-2.1e?  If so, what system did you use and how did you model the fan box part of it?  \n \n The system I have in mind must have the following functionality:\n -VAV\n -DX cooling\n -Evaporative condensing\n -Parallel fan-powered boxes that induce air from a plenum\n -Thermostatically contolled reheat in the VAV box\n \n This is one of the most common types of HVAC systems around, so I am wondering if someone out there has had any more luck than me in attempting to conquer the challanges of accurately modeling its controls & functionality.  \n \n Any thoughts?\n \n \n \n ===========================\n You received this e-mail because you are subscribed \n to the BLDG-SIM at GARD.COM mailing list.  To unsubscribe \n from this mailing list send a blank message to \n BLDG-SIM-UNSUBSCRIBE at GARD.COM'

# %%
BodyList[1]
# Out:
# 'From: miket at etcgrp.com (Mike Tillou)\n Date: Mon, 12 Apr 2004 12:55:46 -0600\n Subject: [BLDG-SIM] Curtain wall frames and fenestration area\n Message-ID: <MDAEMON-F200404121353.AA5358375pd80000085881@gard.com>\n \n Has anyone actually done a comparison to see what sort of effect modeling the frame different ways has on the actual loads in the space.  I realize there is no panacea answer but I would be curious to know what the effect of modeling a single window with enlarged frame area vs actual window size and frame width is.  Is it a 5% difference or a 20% or .05%.  I am curious only because I have always assumed the difference was small and that there were more important (larger impact) modeling items to worry about.  \n  \n Please note that I am not trying to discount the importance of correctly modeling windows but trying to understand the overall impact different modeling techniques might have on output.    \n  \n Mike Tillou\n etc Group, Inc. \n ________________________________\n \n From: postman at gard.com on behalf of Fred Porter\n Sent: Mon 4/12/2004 10:48 AM\n To: BLDG-SIM at gard.com\n Subject: [BLDG-SIM] Curtain wall frames and fenestration area\n \n \n Also, if you are using either of the detailed glazing models, the way Steve describes should better account for edge-of-glass effects. Dividing glazing up into lots of tiny little "panes," as some architects want, has an extemely delterious effect on the IGU overall U-factor, above and beyond the effect of the frame itself. If using the SC inputs, it might be instructive to run Window 5 on some similar configurations, to check the overall U-value with DOE2\'s output. (Noting where interior, exterior etc films are/aren\'t accounted for.)\n \n If you want a pretty rendering for the client, I recommend a separate model, for presentation only. And then if trying to do daylighting calcs......;\n \n stvgates at pacbell.net wrote:\n \n \n \tThe solution below can work, but does not take into account the effect of shading due to fins and overhangs.  For those windows, a better approach is to define one of the windows, together with its fins/overhang, and then use the window MULTIPLIER to establish the total number of windows on the wall wall.  If the overhang shades a significant portion of the wall, in addition to the window, then the overhang can be defined as a separate shading surface.\n \n \t\t----- Original Message ----- \n \t\tFrom:Mike Tillou <mailto:miket at etcgrp.com>  \n \t\tTo:BLDG-SIM at gard.com \n \t\tSent: Monday, April 12, 2004 7:44 AM\n \t\tSubject: [BLDG-SIM] Curtain wall frames and fenestration area\n \n \t\tRenee,\n \t\t \n \t\tThe easiest way to do this is to use a single window on each wall.  Calculate the percentage of window area that is actually frame and then adjust the frame-width to account for the increase.  You may end up with a window frame width that is 12 inches or bigger  (if the wall is large enough).  With a little ingenuity you can write some BDL code that will automatically calculate the window width, frame width and x position of the window on the wall so you don\'t get any cautions or warnings.  .  \n \t\t \n \t\t \n \t\t \n \t\t\n \t\tMichael Tillou, PE\n \t\tetc Group, Inc.\n \t\tPO Box 749,  North Adams, MA 01247\n \t\tPh. (413) 458-9870   Mbl. (413) 652-1087  www.etcgrp.com <http://www.etcgrp.com>  \n \t\t \n \n ________________________________\n \n \t\tFrom: postman at gard.com on behalf of Azerbegi, Renee\n \t\tSent: Mon 4/12/2004 7:44 AM\n \t\tTo: BLDG-SIM at gard.com\n \t\tSubject: [BLDG-SIM] Curtain wall frames and fenestration area\n \t\t\n \t\t\n \n \t\tGreetings,\n \t\t\n \t\tI am modeling a high-rise building in eQuest which has a significant amount of fenestration as curtain wall. This curtain wall, like many curtain walls, has metal frames around many small panes of glass that make up the total curtain wall. My question is, how do you treat the frames and the fenestration area?  If I model each small pane of gla ...

# %%
body_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19591 entries, 0 to 19590
# Data columns (total 1 columns):
# Body    19591 non-null object
# dtypes: object(1)
# memory usage: 153.1+ KB

# %%
bldgsimdata = pd.DataFrame(data=DataList,columns=['From','Date','DateTime','Subject'])
bldgsimdata = pd.concat([bldgsimdata, body_df], axis=1)

NumberPerDay = bldgsimdata.groupby('Date').size()
NumberPerDayIndex = pd.DatetimeIndex(NumberPerDay.index)
NumberPerDay=NumberPerDay.reindex(index=NumberPerDayIndex)
NumberPerMonth = NumberPerDay.resample('M').sum()

AggSubjects = bldgsimdata.groupby('Subject').size()

PeopleFreq = bldgsimdata.groupby('From').size()
# PeopleFreq = PeopleFreq.sort()

monthgrouped = NumberPerDay.groupby(lambda x: x.month)
monthlystats = monthgrouped.agg({'monthlysum': np.sum, 'dailymean': np.mean})
# Out:
# /Users/nus/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:16: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   app.launch_new_instance()

# %%
#AggSubjects

# %%
bldgsimdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19591 entries, 0 to 19590
# Data columns (total 5 columns):
# From        19591 non-null object
# Date        19591 non-null object
# DateTime    19591 non-null datetime64[ns]
# Subject     19591 non-null object
# Body        19591 non-null object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 765.3+ KB

# %%
#PeopleFreq.sort_values()

# %%
bldgsimdata
# Out:
#                                                     From        Date  \
# 0                    miket at etcgrp.com (Mike Tillou)\n  2004-04-12
# 1               Vikram at ensargroup.com (Vikram Sami)\n  2004-04-12
# 2              fporter at archenergy.com (Fred Porter)\n  2004-04-12
# 3            cbarnaby at wrightsoft.com (Chip Barnaby)\n  2004-04-12
# 4       stvgates at pacbell.net (stvgates at pacbell....  2004-04-12
# 5                astevens at dmiinc.com (Alec Stevens)\n  2004-04-12
# 6                    miket at etcgrp.com (Mike Tillou)\n  2004-04-12
# 7          razerbegi at rmhgroup.com (Azerbegi, Renee)\n  2004-04-12
# 8                        cj at cr-jay.ca (Chris Jones)\n  2004-04-12
# 9                dlombard at retec.com (Debra Lombard)\n  2004-04-07
# 10               dlombard at retec.com (Debra Lombard)\n  2004-04-07
# 11              mroberts20 at kc.rr.com (Mike Roberts)\n  2004-04-07
# 12          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 13      Aziz.Laouadi at nrc-cnrc.gc.ca (Laouadi, Aziz)\n  2004-04-07
# 14          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 15          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 16          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 17          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 18          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 19          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 20          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 21          cjprocha at yahoo.com (Caroline Prochazka)\n  2004-04-07
# 22                    esim at NRCan.gc.ca (ES.SE ESim)\n  2004-04-02
# 23            Varkie.Thomas at som.com (Varkie Thomas)\n  2004-04-02
# 19570  From: nshank at dmu.ac.uk (Neil Shankland)\n D...
# 19571  From: bthornton at glumac.com (Brian Thornton)...
# 19572  From: Drury.Crawley at EE.DOE.GOV (Drury.Crawl...
# 19573  From: Dominique.Michaud at dessausoprin.com (D...
# 19574  From: Drury.Crawley at EE.DOE.GOV (Drury.Crawl...
# 19575  From: Drury.Crawley at EE.DOE.GOV (Drury.Crawl...
# 19576  From: mcase at etcgrp.com (Mark E. Case)\n Dat...
# 19577  From: perry.steiner at facilities.gatech.edu (...
# 19578  From: werner at cstb.fr (Werner Keilholz)\n Da...
# 19579  From: jon at esru.strath.ac.uk (jon hand)\n Da...
# 19580  From: bhandari at ecs.umass.edu (Mahabir Bhand...
# 19581                                                 \n
# 19582  From: JJHirsch at ez2.net (James J. Hirsch)\n ...
# 19583  From: mjwitte at gard.com (Michael J. Witte)\n...
# 19584  From: vic at pear-trees.demon.co.uk (Victor Ha...
# 19585  From: jglazer at gard.com (Jason Glazer)\n Dat...
# 19586  From: fcw at pegasus.lbl.gov (Fred Winkelmann)...
# 19587  From: jglazer at gard.com (Jason Glazer)\n Dat...
# 19588  From: Mmullins at hecenergy.com (Mark Mullins)...
# 19589  From: jpkarasa at cbg-engrs.com (John P. Karas...
# 19590  From: Mmullins at hecenergy.com (Mark Mullins)...
#
# [19591 rows x 5 columns]

# %%
bldgsimdata.sort_values("Date")
# Out:
#                                                    From        Date  \
# 2446               jglazer at gard.com (Jason Glazer)\n  1999-03-04
# 2451   Robert.Sonderegger at SRC-Systems.com (Robert...  1999-03-04
# 2452   Robert.Sonderegger at SRC-Systems.com (Robert...  1999-03-04
# 2453          Todd.Taylor at pnl.gov (Z. Todd Taylor)\n  1999-03-04
# 2454               jglazer at gard.com (Jason Glazer)\n  1999-03-04
# 2455             kelsey at kw-energy.com (Jim Kelsey)\n  1999-03-04
# 2456              rdavis at oarsman.com (Randy Davis)\n  1999-03-04
# 2457   RBSPURLO at southernco.com (Spurlock, R. Bruc...  1999-03-04
# 2458             bseaton at ASHRAE.org (Seaton, Bill)\n  1999-03-04
# 2459       bradley at sel.me.wisc.edu (David Bradley)\n  1999-03-04
# 2460               jglazer at gard.com (Jason Glazer)\n  1999-03-04
# 2448               jglazer at gard.com (Jason Glazer)\n  1999-03-04
# 2447   Robert.Sonderegger at SRC-Systems.com (Robert...  1999-03-04
# 2449          Todd.Taylor at pnl.gov (Z. Todd Taylor)\n  1999-03-04
# 2445              rdavis at oarsman.com (Randy Davis)\n  1999-03-04
# 2444          Todd.Taylor at pnl.gov (Z. Todd Taylor)\n  1999-03-04
# 2450            kemerson at psco.com (Emerson, Keith)\n  1999-03-04
# 2443            tconlon at geopraxis.com (Tom Conlon)\n  1999-03-05
# 2442               jglazer at gard.com (Jason Glazer)\n  1999-03-09
# 2441              hvac at together.net (Tom Anderson)\n  1999-03-09
# 2440         thong at supersym.com.sg (Tianzhen HONG)\n  1999-03-10
# 2439            BKoran at aol.com (BKoran at aol.com)\n  1999-03-10
# 2438         rprochot at mag-net.com (Ronald Prochot)\n  1999-03-10
# 2437                      romer at ecn.nl (Jan Romer)\n  1999-03-11
# 2431             kelsey at kw-energy.com (Jim Kelsey)\n  1999-03-11
# 2432               jglazer at gard.com (Jason Glazer)\n  1999-03-11
# 2433               jglazer at gard.com (Jason Glazer)\n  1999-03-11
# 2436      vlado at gundog.lbl.gov (Vladimir Bazjanac)\n  1999-03-11
# 2434   Drury.Crawley at ee.doe.gov (Drury.Crawley at...  1999-03-11
# 2435      vlado at gundog.lbl.gov (Vladimir Bazjanac)\n  1999-03-11
# ...                                                 ...         ...
# 7345   arpan.bakshi at performance.network (arpan.ba...  2015-08-17
# 7346   David.Cocking at designbuilder.co.uk (David C...  2015-08-18
# 7347   ravi.s.srinivasan at gmail.com (Ravi Srinivas...  2015-08-18
# 7348         ghampsmire at usgbc.org (Gail Hampsmire)\n  2015-08-19
# 7349         p.raftery at berkeley.edu (Paul Raftery)\n  2015-08-19
# 7351             sayala81 at gmail.com (Steven Ayala)\n  2015-08-21
# 7350   AChapin at sriregistrar.com (AChapin at srire...  2015-08-21
# 7354             Amir.Roth at EE.Doe.Gov (Roth, Amir)\n  2015-08-24
# 7352   David.Cocking at designbuilder.co.uk (David C...  2015-08-24
# 7353   arpan.bakshi at performance.network (arpan.ba...  2015-08-24
# 7356        bosworth at buildlab.net (David Bosworth)\n  2015-08-25
# 7355               meninbm at gmail.com (Boris Menin)\n  2015-08-25
# 7368   Christopher.r.Jones at wspgroup.com (Jones, C...  2015-08-26
# 7357   yjhuang at whiteboxtechnologies.com (Joe Huan...  2015-08-26
# 7369   hsamuelson at gsd.harvard.edu (Samuelson, Hol...  2015-08-26
# 7367        Cory.Duggin at tlc-eng.com (Duggin, Cory)\n  2015-08-26
# 7366   Julien.Dutel at mern.gouv.qc.ca (Julien.Dutel...  2015-08-26
# 7364      bbishop at pathfinder-ea.com (Bishop, Bill)\n  2015-08-26
# 7363        Cory.Duggin at tlc-eng.com (Duggin, Cory)\n  2015-08-26
# 7365   Julien.Dutel at mern.gouv.qc.ca (Julien.Dutel...  2015-08-26
# 7361   Julien.Dutel at mern.gouv.qc.ca (Julien.Dutel...  2015-08-26
# 7360              javedvit at gmail.com (Javed Iqbal)\n  2015-08-26
# 7359   Christopher.r.Jones at wspgroup.com (Jones, C...  2015-08-26
# 7358   Julien.Dutel at mern.gouv.qc.ca (Julien.Dutel...  2015-08-26
# 7362   mike.karpman at karpmanconsulting.net (Mike K...  2015-08-26
# 7374                       slv3sat at gmail.com (R B)\n  2015-08-27
# 7370             dbcrawley at gmail.com (Dru Crawley)\n  2015-08-27
# 7371   chris.malcolm.yates at gmail.com (Chris Yates)\n  2015-08-27
# 7372   jim at buildingperformanceteam.com (Jim Dirke...  2015-08-27
# 7373                jhaberl at tamu.edu (Jeff Haberl)\n  2015-08-27
#
#                 DateTime                                            Subject  \
# 2446 1999-03-04 16:09:24                            DOE-2 Tip on ##elseif\n
# 2451 1999-03-04 11:36:06                                             site\n
# 2452 1999-03-04 11:25:56                                           there?\n
# 2453 1999-03-04 11:24:11                                           there?\n
# 7348  From: ghampsmire at usgbc.org (Gail Hampsmire)...
# 7349  From: p.raftery at berkeley.edu (Paul Raftery)...
# 7351  From: sayala81 at gmail.com (Steven Ayala)\n D...
# 7350  From: AChapin at sriregistrar.com (AChapin at ...
# 7354  From: Amir.Roth at EE.Doe.Gov (Roth, Amir)\n D...
# 7352  From: David.Cocking at designbuilder.co.uk (Da...
# 7353  From: arpan.bakshi at performance.network (arp...
# 7356  From: bosworth at buildlab.net (David Bosworth...
# 7355  From: meninbm at gmail.com (Boris Menin)\n Dat...
# 7368  From: Christopher.r.Jones at wspgroup.com (Jon...
# 7357  From: yjhuang at whiteboxtechnologies.com (Joe...
# 7369  From: hsamuelson at gsd.harvard.edu (Samuelson...
# 7367  From: Cory.Duggin at tlc-eng.com (Duggin, Cory...
# 7366  From: Julien.Dutel at mern.gouv.qc.ca (Julien....
# 7364  From: bbishop at pathfinder-ea.com (Bishop, Bi...
# 7363  From: Cory.Duggin at tlc-eng.com (Duggin, Cory...
# 7365  From: Julien.Dutel at mern.gouv.qc.ca (Julien....
# 7361  From: Julien.Dutel at mern.gouv.qc.ca (Julien....
# 7360  From: javedvit at gmail.com (Javed Iqbal)\n Da...
# 7359  From: Christopher.r.Jones at wspgroup.com (Jon...
# 7358  From: Julien.Dutel at mern.gouv.qc.ca (Julien....
# 7362  From: mike.karpman at karpmanconsulting.net (M...
# 7374                                                 \n
# 7370  From: dbcrawley at gmail.com (Dru Crawley)\n D...
# 7371  From: chris.malcolm.yates at gmail.com (Chris ...
# 7372  From: jim at buildingperformanceteam.com (Jim ...
# 7373  From: jhaberl at tamu.edu (Jeff Haberl)\n Date...
#
# [19591 rows x 5 columns]

# %%
# bldgsimdata['name'] = bldgsimdata.From.apply(lambda x: re.findall('\(([^)]+)', x))
# bldgsimdata['name'] = bldgsimdata['name']

# %%
#type(bldgsimdata.name.ix[1])

# %% [markdown]
# # Get data from .mbox
#
# https://gist.github.com/shkesar/be9009d83b82548edd16cd5a7d300457

# %%
from mailbox import mbox
import csv

def store_content(message, body=None):
    if not body:
        body = message.get_payload(decode=True)
    if len(message):
        contents = {
            "subject": message['subject'] or "",
            "body": body,
            "from": message['from'],
            "to": message['to'],
            "date": message['date'],
            "labels": message['X-Gmail-Labels'],
            "epilogue": message.epilogue,
        }
        return df.append(contents, ignore_index=True)

# Create an empty DataFrame with the relevant columns
df = pd.DataFrame(
    columns=("subject", "body", "from", "to", "date", "labels", "epilogue"))

# Import your downloaded mbox file
box = mbox('/Users/nus/bldgsim-topicmodeling/mbox-to-txt-master/2015-05-06_2018-11-08-bldg-sim-onebuilding.org.mbox')

fails = []
for message in box:
    try:
        if message.get_content_type() == 'text/plain':
            df = store_content(message)
        elif message.is_multipart():
            # plaintext from multipart messages
            for part in message.get_payload():
                if part.get_content_type() == 'text/plain':
                    df = store_content(message, part.get_payload(decode=True))
                    break
    except:
        fails.append(message)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1846 entries, 0 to 1845
# Data columns (total 7 columns):
# subject     1846 non-null object
# body        1845 non-null object
# from        1846 non-null object
# to          1845 non-null object
# date        1846 non-null object
# labels      0 non-null object
# epilogue    1376 non-null object
# dtypes: object(7)
# memory usage: 101.0+ KB

# %%
df['from']
# Out:
# 0       "Christian Stalberg" <christian@naturalintelli...
# 1       "Soto-Alvarez, Diana" <DSoto-Alvarez@cosentini...
# 2         Joe Chappell <Joe.Chappell@designengineers.com>
# 3           Evgenia Gorbachinsky <gorbachinsky@gmail.com>
# 4                   Nathan Miller <nathanm@rushingco.com>
# 5                    "Sami, Vikram" <vikram.sami@zgf.com>
# 6                  Chris Murphy <cmurphy@cenergistic.com>
# 7                     Nikola Kravik <NKravik@willdan.com>
# 8                    Rathna Shree <rathnashreep@yahoo.in>
# 9            Jim Dirkes <jim@buildingperformanceteam.com>
# 10                  Gail Hampsmire <ghampsmire@usgbc.org>
# 11                Christina Hopfe <C.J.Hopfe@lboro.ac.uk>
# 12                   "Raslan, Rokia" <r.raslan@ucl.ac.uk>
# 13                        Jason Glazer <jglazer@gard.com>
# 14      "Christian Stalberg" <christian@naturalintelli...
# 15              "Jones, Christopher" <cjones@halsall.com>
# 16       Dennis Knight <dknight@wholebuildingsystems.com>
# 17      "Christian Stalberg" <christian@naturalintelli...
# 18              "Cheryl M. Saldanha" <CMSaldanha@sgh.com>
# 19                Christina Hopfe <C.J.Hopfe@lboro.ac.uk>
# 20              Victoria Lieding <vlieding@VACOMTECH.com>
# 21           Joe Huang <yjhuang@whiteboxtechnologies.com>
# 22        "=?gb18030?B?wOTD5rqux7k=?=" <503271081@qq.com>
# 23           Joe Huang <yjhuang@whiteboxtechnologies.com>
# 24      "Christian Stalberg" <christian@naturalintelli...
# 25                    Robin Mitchell <rdmitchell@lbl.gov>
# 26                           Wookey <wookey@wookware.org>
# 27                      Erik Olsen <Olsen@Transsolar.com>
# 28                 David BRADLEY <d.bradley@tess-inc.com>
# 29                "West, Scott P" <Scott.West@jacobs.com>
#                               ...
# 1816    Aaron Boranian <aaron.boranian@bigladdersoftwa...
# 1817                   Michael J Witte <mjwitte@gard.com>
# 1818            Sven Moosberger <sven.moosberger@equa.ch>
# 1819        "Macumber, Daniel" <Daniel.Macumber@nrel.gov>
# 1820            Tobias Maile <Tobias.Maile@D-Alchemy.com>
# 1821    The Energy Simulation Academy <info@simulate.e...
# 1822                  Apoorv Goyal <apoorv.goyal@hok.com>
# 1823                    Steven Ayala <sayala81@gmail.com>
# 1824                  Tarek Rakha <rakha.tarek@gmail.com>
# 1825        Sandeep Ahuja <sandeep.ahuja@patternarch.com>
# 1826                    Steven Ayala <sayala81@gmail.com>
# 1827                     Michael Wetter <mwetter@lbl.gov>
# 1828                "Weili Xu" <weili.xu@buildsimhub.net>
# 1829                "Stephen Roth" <sroth@carmelsoft.com>
# 1830                    Steven Ayala <sayala81@gmail.com>
# 1831                 Tim McDowell <mcdowell@tess-inc.com>
# 1832    The Energy Simulation Academy <info@simulate.e...
# 1833                    Steven Ayala <sayala81@gmail.com>
# 1834                    Dru Crawley <dbcrawley@gmail.com>
# 1835        Sandeep Ahuja <sandeep.ahuja@patternarch.com>
# 1836                 Tim McDowell <mcdowell@tess-inc.com>
# 1837                    Steven Ayala <sayala81@gmail.com>
# 1838                   Christoph Reinhart <tito_@mit.edu>
# 1839                 Tim McDowell <mcdowell@tess-inc.com>
# 1840                  Matt Jungclaus <mjungclaus@rmi.org>
# 1841    =?iso-8859-1?Q?Micha=EBl_Kummert?= <michael.ku...
# 1842                    Steven Ayala <sayala81@gmail.com>
# 1843    The Energy Simulation Academy <info@simulate.e...
# 1844                    Steven Ayala <sayala81@gmail.com>
# 1845              Paul Riemer <Paul.Riemer@dunhameng.com>
# Name: from, Length: 1846, dtype: object

# %%
df.body[1]
# Out:
# "Good Afternoon,  We have an Energy Modeling Analyst position available in our New York City office.  Please see job description details below.\n\nEnergy Modeling Analyst                                             New York, NY\n\nCosentini Associates (www.cosentini.com<http://www.cosentini.com>), a Tetra Tech company, is seeking an Energy Modeling Analyst to join our high performance buildings team. Cosentini is an international engineering firm specializing in building systems design for a range of projects, including office and residential buildings, laboratories, retail, academic and government facilities, museums, tenant interiors and more.\n\nAbout this opportunity:\nYour projects will typically involve advanced energy modeling analysis for high rise commercial and residential buildings.  You will collect data, build models and perform simulations using contract documents prepared by the project Architect and Engineer. You will write reports communicating energy analysis findings, report design recommendations for improved energy performance and complete associated LEED documentation.  Experienced candidates with strong communication skills may attend project meetings and manage client interactions supporting energy-related decision making on Cosentini projects.\n\nWhat's so great about this job?\nThis is an excellent opportunity to gain experience designing energy efficient and sustainable systems for innovative building projects. This position offers career challenge and growth and provides access to a market-leading compensation and benefits package.\n\nWhat kind of candidate are we looking for?\nWe are seeking a highly motivated, detail oriented and deadline driven Energy Modeling Analyst with a B.S. in Mechanical Engineering.   The ideal candidate will have a minimum of three years of experience designing energy systems, performing iterative energy analysis for large scale commercial and residential buildings, analyzing results, and reporting recommendations to clients.  Candidates must be proficient in eQuest for Energy Code compliance, LEED certification and incentive programs.  Knowledge of the LEED Green Building Rating System as it pertains to building energy performance is required.  Candidates must provide at least three large scale new construction reference projects for which they performed the entire energy analysis.  Reference projects must be LEED Certified or the energy analysis must be approved by GBCI.\n\nThe successful candidate will have excellent technical, communication and interpersonal skills as well as fluency in Revit, AutoCAD and Google Sketch Up.  Individuals must possess a strong HVAC design background with an interest in building energy efficiency and highly detailed analysis.   Preference will be given to those with Energy Plus experience Energy Plus and BEMP certification.\nWhy join Cosentini?\nCosentini Associates provides the following engineering services: HVAC, Electrical Power, Fire Protection, Plumbing, Energy Conservation and Sustainable Design, Code Consulting and Construction Administration Services. We have a reputation for innovative design in the global design and construction industry. As part of the Tetra Tech family, we are a leading provider of consulting, engineering, and technical services worldwide. We are a diverse company, including individuals with expertise in science, research, engineering, construction, and information technology. Our strength is in collectively providing integrated services-delivering the best solutions to meet our clients' needs. With more than 13,000 employees, 300 offices worldwide and 2.5 billion revenue in 2014, we provide services to protect and improve the quality of life through responsible resource management, sound infrastructure, and rapid communications ability.\n\nPlease submit your resume and cover letter online via the link https://tetratech.taleo.net/careersection/2/jobsearch.ftl?lang=en&portal=101430233 (The Tetra Tech website). ...

# %% [markdown]
# Get the message contents from files - old way that's not used anymore

# %%
# out_array = []
# snippets = []


# for file in filelist:
#     i=0
#     openfile = open(file)
#     linelist = [line for line in openfile.readlines()]
#     linelistmax=len(linelist)
#     print "Processing "+file

#     with open(file, mode="r") as bigfile:
#         for line in bigfile:
#             try:
#                 if line.startswith("From:"):
#                     out_array.append(line)
#                     snippets.append( line[0:min(len(line),100)] )
#                 else:
#                     out_array[-1] += line
#             except:
#                 print line

# %% [markdown]
# # Create an Array for the tfidf process

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1846 entries, 0 to 1845
# Data columns (total 7 columns):
# subject     1846 non-null object
# body        1845 non-null object
# from        1846 non-null object
# to          1845 non-null object
# date        1846 non-null object
# labels      0 non-null object
# epilogue    1376 non-null object
# dtypes: object(7)
# memory usage: 101.0+ KB

# %%
df = df.fillna("x")

# %%
bldgsimdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19591 entries, 0 to 19590
# Data columns (total 5 columns):
# From        19591 non-null object
# Date        19591 non-null object
# DateTime    19591 non-null datetime64[ns]
# Subject     19591 non-null object
# Body        19591 non-null object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 765.3+ KB

# %%
out_array_old = np.array(bldgsimdata.fillna("x").Body.astype('U'))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-166-c0c494f1aab1> in <module>()
# ----> 1 out_array_old = np.array(bldgsimdata.fillna("x").Body.astype('U'))
#
# /Users/nus/anaconda/lib/python2.7/site-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /Users/nus/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# /Users/nus/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# /Users/nus/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# /Users/nus/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /Users/nus/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# /Users/nus/anaconda/lib/python2.7/site-packages/pandas/core/dtypes/cast.pyc in astype_nansafe(arr, dtype, copy)
#     653     if issubclass(dtype.type, text_type):
#     654         # in Py3 that's str, in Py2 that's unicode
# --> 655         return lib.astype_unicode(arr.ravel()).reshape(arr.shape)
#     656
#     657     elif issubclass(dtype.type, string_types):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_unicode()
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_unicode()
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe2 in position 484: ordinal not in range(128)

# %%
out_array_new = np.array(df['from']+" "+df["date"]+" "+df["subject"]+" "+df["body"])

# %%
len(out_array_old)
# Out:
# 19591

# %%
out_array = np.concatenate([out_array_old,out_array_new])

# %%
len(out_array)
# Out:
# 21437

# %% [markdown]
# # Stop words from the bodies

# %%
os.chdir("/Users/nus/twenty-years-of-bldgsim-textmining/")

# %%
custom_stop_words = []
with open( "stopwords.txt", "r" ) as fin:
    for line in fin.readlines():
        custom_stop_words.append( line.strip() )
# note that we need to make it hashable
print("Stopword list has %d entries" % len(custom_stop_words) )
# Out:
# Stopword list has 1149 entries

# %%
from sklearn.feature_extraction.text import CountVectorizer
# use a custom stopwords list, set the minimum term-document frequency to 20
vectorizer = CountVectorizer(stop_words = custom_stop_words, min_df = 20, encoding='latin-1')
A = vectorizer.fit_transform(out_array)
print( "Created %d X %d document-term matrix" % (A.shape[0], A.shape[1]) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-3e4b6463aaf0> in <module>()
#       2 # use a custom stopwords list, set the minimum term-document frequency to 20
#       3 vectorizer = CountVectorizer(stop_words = custom_stop_words, min_df = 20, encoding='latin-1')
# ----> 4 A = vectorizer.fit_transform(out_array)
#       5 print( "Created %d X %d document-term matrix" % (A.shape[0], A.shape[1]) )
#
# /Users/nus/anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# /Users/nus/anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# /Users/nus/anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# /Users/nus/anaconda/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in decode(self, doc)
#     117
#     118         if doc is np.nan:
# --> 119             raise ValueError("np.nan is an invalid document, expected byte or "
#     120                              "unicode string.")
#     121
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.

# %%
# extract the resulting vocabulary
terms = vectorizer.get_feature_names()
print("Vocabulary has %d distinct terms" % len(terms))

# %%
from sklearn.externals import joblib
joblib.dump((A,terms), "emails-raw.pkl")

# %% [markdown]
# # TFIDF Weighting

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# we can pass in the same preprocessing parameters
vectorizer = TfidfVectorizer(stop_words=custom_stop_words, min_df = 20, encoding='latin-1')
A = vectorizer.fit_transform(out_array)
print("Created %d X %d TF-IDF-normalized document-term matrix" % (A.shape[0], A.shape[1]) )

# %%
import operator
def rank_terms( A, terms ):
    # get the sums over each column
    sums = A.sum(axis=0)
    # map weights to the terms
    weights = {}
    for col, term in enumerate(terms):
        weights[term] = sums[0,col]
    # rank the terms by their weight over all documents
    return sorted(weights.items(), key=operator.itemgetter(1), reverse=True)

# %%
ranking = rank_terms( A, terms )
for i, pair in enumerate( ranking[0:200] ):
    print( "%s" % (pair[0]) )

# %%
#ranking

# %%
snippets[:1]
# Out:
# ['From: miket at etcgrp.com (Mike Tillou)\n']

# %%
joblib.dump((A,terms, snippets), "emails-tfidf.pkl")
# Out:
# ['emails-tfidf.pkl']
