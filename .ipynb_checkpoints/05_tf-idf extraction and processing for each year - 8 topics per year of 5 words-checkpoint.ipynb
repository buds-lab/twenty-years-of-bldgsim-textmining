# %% [markdown]
# # Cycle through each year and extract the major topics

# %%
import os
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
import operator
from sklearn.externals import joblib
from sklearn import decomposition

# %%
# %matplotlib inline

# %%
total_bldgsim = pd.read_pickle("/Users/nus/twenty-years-of-bldgsim-textmining/total_email_data.pkl")

# %%
total_bldgsim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20029 entries, 1999-03-04 08:26:46 to 2018-11-08 18:42:22
# Data columns (total 4 columns):
# From        20029 non-null object
# DateTime    20029 non-null datetime64[ns]
# Subject     20029 non-null object
# Body        20028 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 782.4+ KB

# %% [markdown]
# # Loop through each year and calculate the tf-idf and the topics for each year

# %%
def rank_terms( A, terms ):
    # get the sums over each column
    sums = A.sum(axis=0)
    # map weights to the terms
    weights = {}
    for col, term in enumerate(terms):
        weights[term] = sums[0,col]
    # rank the terms by their weight over all documents
    return sorted(weights.items(), key=operator.itemgetter(1), reverse=True)

# %%
def get_descriptor( terms, H, topic_index, top ):
    # reverse sort the values to sort the indices
    top_indices = np.argsort( H[topic_index,:] )[::-1]
    # now get the terms corresponding to the top-ranked indices
    top_terms = []
    for term_index in top_indices[0:top]:
        top_terms.append( terms[term_index] )
    return top_terms

# %%
k = 10

# %% [markdown]
# # Run through each year, get the top 10 topics and their top 10 words
#
# Put them in a dataframe with the year

# %%
all_topics = []

# %%
for year in total_bldgsim.index.year.unique():
    bldg_sim_peryear = total_bldgsim[total_bldgsim.index.year == year]
    out_array = np.array(bldg_sim_peryear.fillna("x").Body)
    custom_stop_words = []
    with open( "/Users/nus/twenty-years-of-bldgsim-textmining/stopwords_annual_analysis_3.txt", "r" ) as fin:
        for line in fin.readlines():
            custom_stop_words.append( line.strip() )
    print(year)
    
    # use a custom stopwords list, set the minimum term-document frequency to 20
    vectorizer = CountVectorizer(stop_words = custom_stop_words, min_df = 20, encoding='latin-1')
    A = vectorizer.fit_transform(out_array)
    print( "Created %d X %d document-term matrix" % (A.shape[0], A.shape[1]) )
    
    # extract the resulting vocabulary
    terms = vectorizer.get_feature_names()
    print("Vocabulary has %d distinct terms" % len(terms))
    
    # we can pass in the same preprocessing parameters
    vectorizer = TfidfVectorizer(stop_words=custom_stop_words, min_df = 20, encoding='latin-1')
    A = vectorizer.fit_transform(out_array)
    print("Created %d X %d TF-IDF-normalized document-term matrix" % (A.shape[0], A.shape[1]) )
    
    joblib.dump((A,terms), "/Users/nus/twenty-years-of-bldgsim-textmining/emails-raw"+str(year)+".pkl") 
    
    (A,terms) = joblib.load( "/Users/nus/twenty-years-of-bldgsim-textmining/emails-raw"+str(year)+".pkl" )
    print( "Loaded %d X %d document-term matrix" % (A.shape[0], A.shape[1]) )
    
    model = decomposition.NMF( init="nndsvd", n_components=k ) 
    # apply the model and extract the two factor matrices
    W = model.fit_transform( A )
    H = model.components_
    
    descriptors = []
    for topic_index in range(k):
        descriptors.append( get_descriptor( terms, H, topic_index, 10) )
        str_descriptor = ", ".join( descriptors[topic_index] )
        print("Topic %02d: %s" % ( topic_index+1, str_descriptor ) )
        
    descriptors_df = pd.DataFrame(descriptors).T
    descriptors_df['year'] = year
    all_topics.append(descriptors_df)
# Out:
# 1999
# Created 152 X 42 document-term matrix
# Vocabulary has 42 distinct terms
# Created 152 X 42 TF-IDF-normalized document-term matrix
# Loaded 152 X 42 document-term matrix
# Topic 01: doe, 1e, user, version, 0400, input, text, experience, 0700, project
# Topic 02: ashrae, bill, 0400, large, interested, 0500, jun, looking, references, text
# Topic 03: jason, administrator, consultant, analytics, user, wrote, 0600, input, 0500, text
# Topic 04: number, jun, see, large, bill, better, hourly, 04, phone, doe
# Topic 05: systems, better, available, source, text, large, web, tools, 04, interested
# Topic 06: thermal, program, interested, web, tools, project, phone, 0500, see, version
# Topic 07: software, experience, looking, 0600, better, tools, 04, web, program, version
# Topic 08: source, hourly, wrote, good, 0700, 1e, interested, references, looking, program
# Topic 09: research, project, 0700, phone, good, jun, program, experience, available, analytics
# Topic 10: information, interested, looking, site, web, good, bill, available, tools, phone
# 2000
# Created 234 X 131 document-term matrix
# Vocabulary has 131 distinct terms
# Created 234 X 131 TF-IDF-normalized document-term matrix
# Loaded 234 X 131 document-term matrix
# Topic 01: doe2, hornets, things, people, nest, energyplus, code, good, hirsch, tools
# Topic 02: weather, hourly, website, 0500, different, find, appreciated, street, source, phone
# Topic 03: heat, water, air, temperature, looking, source, phone, 0500, 0600, analytics
# Topic 04: software, development, effort, university, available, performance, applications, pnl, equipment, national
# Topic 05: ashrae, research, projects, systems, engineer, commercial, information, 0400, site, web
# Topic 06: public, private, open, source, software, investment, hirsch, sector, jeff, version
# Topic 07: doe, program, energyplus, user, engineering, input, systems, information, version, interface
# Topic 08: john, systems, free, private, modeling, high, 0800, heat, see, interested
# Topic 09: powerdoe, 0500, modeling, temperature, hvac, input, including, project, interface, find
# Topic 10: mark, case, group, 0600, commercial, jun, program, go, find, experience
# 2001
# Created 211 X 77 document-term matrix
# Vocabulary has 77 distinct terms
# Created 211 X 77 TF-IDF-normalized document-term matrix
# Loaded 211 X 77 document-term matrix
# Topic 01: jason, problem, today, gpc18, analytics, administrator, il, park, ridge, busse
# Topic 02: weather, looking, source, group, advance, engineer, street, question, university, free
# Topic 03: trnsys, university, engineering, 0100, ext, web, project, 0500, phone, looking
# Topic 04: doe, available, information, size, 0500, street, 0700, find, web, engineer
# Topic 05: people, corp, vice, st, president, 862, ma, voice, suite, usa
# Topic 06: doe2, heat, 1e, temperature, 0400, ext, suite, engineer, phone, program
# Topic 07: loads, office, power, equipment, 05, hvac, wrote, ashrae, references, il
# Topic 08: research, ashrae, information, group, engineering, systems, university, based, hvac, question
# Topic 09: software, program, programs, size, experience, jun, available, people, web, engineer
# Topic 10: load, question, systems, 0500, hvac, program, source, interested, project, temperature
# 2002
# Created 247 X 137 document-term matrix
# Vocabulary has 137 distinct terms
# Created 247 X 137 TF-IDF-normalized document-term matrix
# Loaded 247 X 137 document-term matrix
# Topic 01: hvac, engineering, information, projects, interested, software, web, free, experience, university
# Topic 02: jason, il, analytics, busse, highway, park, ridge, admin, users, 0500
# Topic 03: powerdoe, dmiinc, ma, dmi, savings, 02466, newton, lexington, 6606, st
# Topic 04: energyplus, programs, available, user, version, surface, lbl, questions, software, web
# Topic 05: doe, 1e, control, modeling, case, based, engineer, performance, project, variable
# Topic 06: weather, sources, architecture, doe2, location, 05, 2002, different, university, find
# Topic 07: water, temperature, heat, surface, temperatures, source, report, load, doe2, thermal
# Topic 08: available, text, size, usa, 0600, 2002, 0500, jun, software, 07
# Topic 09: air, control, information, floor, space, solar, appreciated, cooling, loads, 1e
# Topic 10: systems, 0700, ashrae, 2002, high, cooling, 01, control, find, case
# 2003
# Created 541 X 622 document-term matrix
# Vocabulary has 622 distinct terms
# Created 541 X 622 TF-IDF-normalized document-term matrix
# Loaded 541 X 622 document-term matrix
# Topic 01: equest, doe, sempra, solutions, doe2, curve, utilities, chiller, 1e, john
# Topic 02: air, water, cooling, heat, heating, ventilation, varkie, fan, thomas, demand
# Topic 03: esl, jeff, tamu, haberl, texas, jhaberl, postman, college, station, architecture
# Topic 04: weather, crawley, actual, doe, drury, energyplus, utility, wind, models, typical
# Topic 05: architects, software, tools, architect, getting, hand, team, hvac, tool, 3d
# Topic 06: leed, ashrae, modeling, method, standard, cost, dmiinc, review, occupancy, question
# Topic 07: yahoo, 0800, equest, center, tools, free, read, cooling, results, consumption
# Topic 08: ibpsa, desc, bytes, text, available, size, meeting, issue, tamu, conference
# Topic 09: mass, thermal, wall, value, walls, effect, temperature, concrete, load, house
# Topic 10: jason, admin, highway, busse, park, ridge, analytics, il, users, dot
# 2004
# Created 621 X 801 document-term matrix
# Vocabulary has 801 distinct terms
# Created 621 X 801 TF-IDF-normalized document-term matrix
# Loaded 621 X 801 document-term matrix
# Topic 01: air, vav, equest, flow, fan, oa, cooling, outside, volume, constant
# Topic 02: radiant, heating, systems, temperature, cooling, research, ceiling, dimensional, heat, laouadi
# Topic 03: yahoo, equest, gerald, daylight, pde, promotions, 0800, try, 0700, radiance
# Topic 04: weather, tmy2, energyplus, 0100, information, program, utility, convert, cfm, error
# Topic 05: wall, glass, fenestration, window, walls, group, windows, small, tillou, modeling
# Topic 06: vikram, sami, jason, ensargroup, commercial, _____, ensar, 80304, boulder, conservation
# Topic 07: lighting, varkie, standard, thomas, infiltration, ashrae, doe2, leed, proposed, 1e
# Topic 08: energyplus, ibpsa, shading, pv, trnsys, smita, solar, usa, performance, version
# Topic 09: water, loop, pump, heat, chiller, cooling, load, storage, cooled, kw
# Topic 10: forum, web, questions, alec, based, read, stevens, postings, something, go
# 2005
# Created 812 X 991 document-term matrix
# Vocabulary has 991 distinct terms
# Created 812 X 991 TF-IDF-normalized document-term matrix
# Loaded 812 X 991 document-term matrix
# Topic 01: equest, construction, window, doe2, load, detailed, doe, error, mike, wall
# Topic 02: bb, jeff, haberl, tamu, texas, esl, jeffhaberl, tees, tamus, 3581
# Topic 03: yahoo, spam, gerald, tired, protection, best, pde, geraldpde, 0700, 0800
# Topic 04: green, engineering, studio, experience, commercial, team, engineer, certification, computer, information
# Topic 05: heat, water, recovery, exhaust, pump, loop, hot, exchanger, source, thornton
# Topic 06: thermal, floor, south, mass, lee, temperature, glass, heat, wall, facing
# Topic 07: vikram, sami, direct, lordaecksargent, leed, responsive, aeck, sargent, lord, technological
# Topic 08: energyplus, weather, jason, tmy2, crawley, bin, drury, available, doe, alpana
# Topic 09: ibpsa, news, meeting, conference, usa, days, peter, training, cox, papers
# Topic 10: cooling, air, fan, heating, glumac, oa, flow, systems, exhaust, control
# 2006
# Created 1022 X 1153 document-term matrix
# Vocabulary has 1153 distinct terms
# Created 1022 X 1153 TF-IDF-normalized document-term matrix
# Loaded 1022 X 1153 document-term matrix
# Topic 01: air, cooling, fan, exhaust, supply, vav, recovery, temperature, fans, space
# Topic 02: energyplus, doe, differences, software, crawley, main, drury, run, brian, version
# Topic 03: yahoo, spam, tired, protection, best, aulbach, jra_sac, john, gerald, equest
# Topic 04: natural, ramana, ventilation, koti, appendix, bnim, elements, leed, baseline, ashrae
# Topic 05: equest, vikram, sami, direct, wall, lordaecksargent, aeck, lord, sargent, responsive
# Topic 06: pv, bb, jeff, bipv, texas, esl, tamu, haberl, espr, lab
# Topic 07: kendra, tupper, fk, sf, intended, recipient, flack, kurtz, flackandkurtz, 402
# Topic 08: weather, iwec, doe2, bin, mike, epw, equest, convert, virus, dillon
# Topic 09: ibpsa, software, research, engineering, thermal, university, usa, trnsys, arup, ac
# Topic 10: water, heat, loop, pump, chiller, condenser, ground, curves, source, equest
# 2007
# Created 2217 X 2707 document-term matrix
# Vocabulary has 2707 distinct terms
# Created 2217 X 2707 TF-IDF-normalized document-term matrix
# Loaded 2217 X 2707 document-term matrix
# Topic 01: loop, heat, pump, water, chiller, boiler, karen, heating, cooling, walkerman
# Topic 02: software, developing, studioma, modeling, rosiers, des, robert, studio, recommendations, 251
# Topic 03: baseline, leed, existing, orientation, appendix, ashrae, addendum, addenda, proposed, orientations
# Topic 04: elevator, vikram, elevators, sami, direct, schedule, lordaecksargent, lighting, leed, aeck
# Topic 05: bb, jeff, haberl, tamu, texas, esl, laboratory, blown, jhaberl, 3581
# Topic 06: load, unmet, hours, loads, cooling, zones, process, glass, heating, met
# Topic 07: 206, hargis, brandon, nichols, 448, biz, stewart, 8707, 3376, 228
# Topic 08: fan, nexant, vav, john, 626, 430, aulbach, jaulbach, powered, power
# Topic 09: ramana, koti, bnim, elements, 64105, kansas, division, missouri, 1635, renewable
# Topic 10: equest, yahoo, program, floor, window, error, doe2, windows, forum, roof
# 2008
# Created 2055 X 2351 document-term matrix
# Vocabulary has 2351 distinct terms
# Created 2055 X 2351 TF-IDF-normalized document-term matrix
# Loaded 2055 X 2351 document-term matrix
# Topic 01: equest, weather, floor, program, window, users, doe2, wizard, arup, doe
# Topic 02: air, heat, water, cooling, pump, loop, temperature, fan, supply, heating
# Topic 03: baseline, existing, leed, appendix, ashrae, glazing, requirement, mark, proposed, case
# Topic 04: pae, engineers, jpeg, image, bytes, desc, available, 226, text, size
# Topic 05: bnim, ramana, koti, elements, kansas, missouri, 64105, 1635, division, city
# Topic 06: uk, paul, zed, cfd, carey, fluent, ies, built, ac, software
# Topic 07: esiyok, dortmund, uni, mit, umit, unimail, squirrel, 254, 62, dcmit_esiyok
# Topic 08: hours, unmet, load, linda, lam, loads, report, zones, cooling, heating
# Topic 09: des, plant, step, district, central, thermal, chiller, xu, jeff, proposed
# Topic 10: consultant, daylight, performance, higgins, edi, matthew, arch, opinions, experience, specialist
# 2009
# Created 1652 X 2706 document-term matrix
# Vocabulary has 2706 distinct terms
# Created 1652 X 2706 TF-IDF-normalized document-term matrix
# Loaded 1652 X 2706 document-term matrix
# Topic 01: water, loop, baseline, leed, hot, pump, chilled, district, boiler, equest
# Topic 02: unmet, hours, rosenberg, jim, michael, crockett, nick, pnl, zones, 301
# Topic 03: fan, power, supply, exhaust, kw, cfm, fans, appendix, baseline, total
# Topic 04: air, leakage, infiltration, barrier, ashrae, savings, prosoco, appendix, grahovac, leed
# Topic 05: hay, cost, leed, paul, 876, certification, phcjamaica, costs, 756, 0631
# Topic 06: ies, cfd, energyplus, software, uk, program, thermal, ac, sketchup, available
# Topic 07: loads, cooling, peak, load, doe2, jeff, joe, sizing, doe, haberl
# Topic 08: yahoo, qm, weather, mud, equest, 0700, 0800, energyplus, john, groups
# Topic 09: roof, emissivity, high, roofs, radiation, climates, cool, infrared, warm, chris
# Topic 10: oa, 62, space, unoccupied, occupied, minimum, ventilation, occupancy, michael, guin
# 2010
# Created 1899 X 2557 document-term matrix
# Vocabulary has 2557 distinct terms
# Created 1899 X 2557 TF-IDF-normalized document-term matrix
# Loaded 1899 X 2557 document-term matrix
# Topic 01: nick, lighting, smithboucher, baseline, caton, 913, exterior, proposed, wall, automatic
# Topic 02: modeling, ibpsa, conference, ashrae, experience, leed, exam, usa, workshop, engineering
# Topic 03: john, eurek, nwo, voodoo, varkie, engineering, army, sizing, equipment, mil
# Topic 04: whiteboxtechnologies, joe, doe, source, huang, open, white, yjhuang, technologies, box
# Topic 05: perkinswill, vikram, sami, addressee, chi01exmb, ideas, double, peachtree, society, 7462
# Topic 06: equest, chris, weather, yahoo, users, ies, sadeghipour, mostapha, result, eng
# Topic 07: window, frame, glass, glazing, alex, performance, krickx, shgc, windows, otto
# Topic 08: cooling, air, heating, fan, baseline, heat, water, exhaust, sambhav, vinay
# Topic 09: progressiveae, fareed, syedf, syed, 361, exchange2, supply, 1811, 49525, 3447
# Topic 10: communication, ght, 703, james, hansen, thereof, baseline, limited, leed, ft
# 2011
# Created 1757 X 3064 document-term matrix
# Vocabulary has 3064 distinct terms
# Created 1757 X 3064 TF-IDF-normalized document-term matrix
# Loaded 1757 X 3064 document-term matrix
# Topic 01: fan, power, cooling, supply, water, pump, chiller, heat, fans, eer
# Topic 02: sheffer, leed, cost, marcus, hours, sevengroup, modeling, phase, points, going
# Topic 03: 3d, font, span, style, div, color, nbsp, face, size, 3d2
# Topic 04: chris, comfort, yates, haberl, thermal, weather, jeff, energyplus, tamu, tool
# Topic 05: nick, smithboucher, lighting, caton, 913, equest, jpeg, heating, baseline, users
# Topic 06: epsteinglobal, ce, et, epstein, martin, est, ou, courriel, le, roy
# Topic 07: job, doe, ibpsa, ibpsausa, training, skills, nrel, jta, task, roth
# Topic 08: existing, 858, coto, rob, perkinswill, hudson, vikram, 751, sami, leed
# Topic 09: nwo, unclassified, army, eurek, usace, mil, john, caveats, classification, ml3oma
# Topic 10: air, baseline, ventilation, outdoor, 62, proposed, oa, minimum, doas, case
# 2012
# Created 1228 X 2062 document-term matrix
# Vocabulary has 2062 distinct terms
# Created 1228 X 2062 TF-IDF-normalized document-term matrix
# Loaded 1228 X 2062 document-term matrix
# Topic 01: modeling, leed, ashrae, jeff, guidelines, tamu, experience, performance, haberl, engineering
# Topic 02: cooling, fan, air, heat, load, heating, water, temperature, hap, flow
# Topic 03: cleantech, analytics, cleantechanalytics, sheelam, khare, jeremiah, builder, valuable, sheelamkhare26, consent
# Topic 04: ibpsa, tess, conference, boston, simbuild, madison, usa, trnsys, event, meeting
# Topic 05: bre, uk, wales, registered, england, apeksha, gupta, hvac, establishment, solutions
# Topic 06: fossil, pathfinder, ea, wbishop, electric, baseline, heat, fuel, source, g3
# Topic 07: alex, wichert, robert, mark, jon, setnrgh2o, jeremiah, envelope, colta, peeters
# Topic 08: weather, bin, whiteboxtechnologies, eu, equest, epw, joe, climate, para, nrel
# Topic 09: energyplus_support, yahoo, groups, _ylc, yahoogroups, group, jim, buildingperformanceteam, pavel, energyplus
# Topic 10: training, designbuilder, designbuilderusa, naturalintelligence, energyplus, curriculum, christian, stalberg, scheduled, workshop
# 2013
# Created 2262 X 3703 document-term matrix
# Vocabulary has 3703 distinct terms
# Created 2262 X 3703 TF-IDF-normalized document-term matrix
# Loaded 2262 X 3703 document-term matrix
# Topic 01: ibpsa, energyplus, performance, modeling, uk, university, software, research, mit, conference
# Topic 02: weather, whiteboxtechnologies, joe, binned, huang, yjhuang, locations, iwec2, 0265, 2683
# Topic 03: fan, wichert, seer, robert, power, better, leed, robertwichert, efficiency, motor
# Topic 04: apartments, cooling, diversity, patrick, sizing, load, apartment, bivona, peak, modelling
# Topic 05: thumb, christian, rules, sudassociates, loads, kaltreider, jim, 255, sf, 828
# Topic 06: baseline, proposed, air, ventilation, outdoor, oa, existing, ashrae, cfm, minimum
# Topic 07: rosenberg, michael, pnnl, pnl, iesve, automatic, baseline, generation, models, kegel
# Topic 08: residential, dormitory, floor, floors, nal, definition, basement, rooms, types, university
# Topic 09: wall, roof, mass, thermal, exterior, surface, space, plenum, column, columns
# Topic 10: vikram, sami, zgf, equest, mariana, marianaristi, intended, recipient, javed, llp
# 2014
# Created 1162 X 1972 document-term matrix
# Vocabulary has 1972 distinct terms
# Created 1162 X 1972 TF-IDF-normalized document-term matrix
# Loaded 1162 X 1972 document-term matrix
# Topic 01: ibpsa, performance, leed, image, desc, bytes, size, text, experience, modeling
# Topic 02: plug, loads, aeieng, chris, eac1, yates, leed, equipment, m2, david
# Topic 03: radiation, whiteboxtechnologies, glass, weather, low, value, glazing, joe, coating, winter
# Topic 04: casework, jim, savings, buildingperformanceteam, refrigerated, dirkes, claiming, cop, process, ecm
# Topic 05: fan, curve, reset, vav, archenergy, fred, curves, porter, sp, fporter
# Topic 06: genopt, daysim, command, batch, bat, eplus, energyplus, tavis, runeplus, line
# Topic 07: sriregistrar, achapin, sri, christopher, 724, information, jones, halsall, alex, authorized
# Topic 08: material, properties, mit, christoph, thermal, materials, numbers, library, oc11expo28, sources
# Topic 09: openstudio, psdconsulting, training, webinar, psd, modeling, nrel, free, support, development
# Topic 10: ventilation, jacobs, baseline, credit, rates, increased, 62, leed, karen, scott
# 2015
# Created 846 X 2116 document-term matrix
# Vocabulary has 2116 distinct terms
# Created 846 X 2116 TF-IDF-normalized document-term matrix
# Loaded 846 X 2116 document-term matrix
# Topic 01: actual, app, models, jacob, appendix, iesve, values, nathan, leed, eskewdumezripple
# Topic 02: designbuilder, training, days, architects, energyplus, course, registration, engineers, attend, performance
# Topic 03: julien, lighting, gouv, dutel, des, class, qc, vous, est, space
# Topic 04: utility, bills, plant, days, april, period, wsp, month, degree, billing
# Topic 05: certification, experience, technical, usgbc, leed, skills, team, preferred, engineering, position
# Topic 06: weather, whiteboxtechnologies, tmy3, joe, climate, wichert, epw, huang, white, web
# Topic 07: ibpsa, usa, news, newsletter, subscribe, conference, latest, ac, uk, 2015
# Topic 08: vrf, sefaira, cooling, curves, yahoo, heating, fan, air, doas, heat
# Topic 09: openstudio, radiance, diva, mit, studio, open, daylighting, energyplus, daylight, christoph
# Topic 10: exhaust, fan, baseline, grade, christopher, conditioned, jones, g3, wsp, wall
# 2016
# Created 420 X 636 document-term matrix
# Vocabulary has 636 distinct terms
# Created 420 X 636 TF-IDF-normalized document-term matrix
# Loaded 420 X 636 document-term matrix
# Topic 01: experience, technical, certification, skills, research, leed, green, engineering, team, ability
# Topic 02: openstudio, mc_eid, mc_cid, uniqid, psdconsulting, utm_medium, utm_source, utm_campaign, training, 2feepurl
# Topic 03: ibpsa, usa, conference, news, 0af59bbb65, 2016, meeting, newsletter, image, manage
# Topic 04: weather, whiteboxtechnologies, joe, climate, epw, huang, white, locations, suite, yjhuang
# Topic 05: energyplus, workshop, openstudio, designbuilder, training, eventbrite, bigladdersoftware, software, ladder, workshops
# Topic 06: jones, information, intended, christopher, ontario, thermal, eng, power, communication, toronto
# Topic 07: gototraining, attendee, register, webinar, network, performance, live, organized, grasshopper, series
# Topic 08: jim, dirkes, buildingperformanceteam, linkedin, cgi, listinfo, 8653, ii, ceo, 1631
# Topic 09: water, cooling, heat, air, source, hot, version, cost, chris, electric
# Topic 10: standard, ashrae, review, public, jason, chair, residential, ny, appendix, requirements
# 2017
# Created 406 X 490 document-term matrix
# Vocabulary has 490 distinct terms
# Created 406 X 490 TF-IDF-normalized document-term matrix
# Loaded 406 X 490 document-term matrix
# Topic 01: cgi, tresidder, 40gmail, successfully, entitled, leave, info, messages, 6th, acknowledgement
# Topic 02: network, gototraining, attendee, register, performance, live, 42b11, webinar, recording, cfd
# Topic 03: jim, buildingperformanceteam, dirkes, linkedin, truth, mobile, 8653, bemp, acacia, 49504
# Topic 04: ibpsa, usa, news, newsletter, latest, updates, community, issue, training, manage
# Topic 05: energyplus, openstudio, workshop, bigladdersoftware, training, designbuilder, controls, denver, software, workshops
# Topic 06: weather, joe, whiteboxtechnologies, doe, huang, box, white, yjhuang, technologies, february
# Topic 07: 510, chris, solar, glazing, wrote, uk, green, glass, best, range
# Topic 08: research, engineering, university, experience, environment, technology, systems, institute, based, information
# Topic 09: buildingsimulation2017, ibpsa, image, conference, registration, twitter, facebook, click, linkedin, usa
# Topic 10: ashrae, conference, performance, conferences, leed, modeling, review, standard, available, residential
# 2018
# Created 285 X 413 document-term matrix
# Vocabulary has 413 distinct terms
# Created 285 X 413 TF-IDF-normalized document-term matrix
# Loaded 285 X 413 document-term matrix
# Topic 01: ibpsa, usa, news, uniqid, performance, 0769126d70, board, manage, member, simbuild
# Topic 02: energyplus, openstudio, bigladdersoftware, workshop, training, controls, advanced, workshops, practitioners, index
# Topic 03: weather, solar, whiteboxtechnologies, joe, box, white, yjhuang, huang, technologies, station
# Topic 04: research, control, experience, optimization, engineering, systems, tools, performance, apply, modeling
# Topic 05: tickets, eventbrite, tool, cost, optimization, company, webinar, linkedin, free, create
# Topic 06: lighting, linkedin, value, leed, cgi, listinfo, wrote, designbuilder, annual, pe
# Topic 07: wind, rain, driven, joe, stations, different, speed, urban, uk, field
# Topic 08: webinar, register, performance, denver, attendee, gotowebinar, green, presentation, network, school
# Topic 09: conference, users, modeling, simbuild, presentations, ashrae, conferences, program, performance, 3a
# Topic 10: heating, source, project, thermal, systems, air, case, ashrae, residential, example

# %%
all_topics_df = pd.concat(all_topics).reset_index(drop=True)

# %%
all_topics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
# 0       200 non-null object
# 1       200 non-null object
# 2       200 non-null object
# 3       200 non-null object
# 4       200 non-null object
# 5       200 non-null object
# 6       200 non-null object
# 7       200 non-null object
# 8       200 non-null object
# 9       200 non-null object
# year    200 non-null int64
# dtypes: int64(1), object(10)
# memory usage: 17.3+ KB

# %%
all_topics_df
# Out:
#                    0                  1                        2  \
# 0                doe             ashrae                    jason
# 1                 1e               bill            administrator
# 2               user               0400               consultant
# 3            version              large                analytics
# 4               0400         interested                     user
# 5              input               0500                    wrote
# 6               text                jun                     0600
# 7         experience            looking                    input
# 8               0700         references                     0500
# 9            project               text                     text
# 10              doe2            weather                     heat
# 11           hornets             hourly                    water
# 12            things            website                      air
# 13            people               0500              temperature
# 14              nest          different                  looking
# 15        energyplus               find                   source
# 16              code        appreciated                    phone
# 17              good             street                     0500
# 18            hirsch             source                     0600
# 19             tools              phone                analytics
# 20             jason            weather                   trnsys
# 21           problem            looking               university
# 22             today             source              engineering
# 23             gpc18              group                     0100
# 24         analytics            advance                      ext
# 25     administrator           engineer                      web
# 26                il             street                  project
# 27              park           question                     0500
# 28             ridge         university                    phone
# 29             busse               free                  looking
# ..               ...                ...                      ...
# 170       experience         openstudio                    ibpsa
# 171        technical             mc_eid                      usa
# 172    certification             mc_cid               conference
# 173           skills             uniqid                     news
# 174         research      psdconsulting               0af59bbb65
# 175             leed         utm_medium                     2016
# 176            green         utm_source                  meeting
# 177      engineering       utm_campaign               newsletter
# 178             team           training                    image
# 179          ability           2feepurl                   manage
# 180              cgi            network                      jim
# 181        tresidder       gototraining  buildingperformanceteam
# 182          40gmail           attendee                   dirkes
# 183     successfully           register                 linkedin
# 184         entitled        performance                    truth
# 185            leave               live                   mobile
# 186             info              42b11                     8653
# 187         messages            webinar                     bemp
# 188              6th          recording                   acacia
# 189  acknowledgement                cfd                    49504
# 190            ibpsa         energyplus                  weather
# 191              usa         openstudio                    solar
# 192             news  bigladdersoftware     whiteboxtechnologies
# 193           uniqid           workshop                      joe
# 194      performance           training                      box
# 195       0769126d70           controls                    white
# 196            board           advanced                  yjhuang
# 197           manage          workshops                    huang
# 198           member      practitioners             technologies
# 199         simbuild              index                  station
#
#                         3                  4                     5  \
# 0                  number            systems               thermal
# 1                     jun             better               program
# 2                     see          available            interested
# 3                   large             source                   web
# 4                    bill               text                 tools
# 5                  better              large               project
# 6                  hourly                web                 phone
# 7                      04              tools                  0500
# 8                   phone                 04                   see
# 9                     doe         interested               version
# 10               software             ashrae                public
# 11            development           research               private
# 12                 effort           projects                  open
# 13             university            systems                source
# 14              available           engineer              software
# 15            performance         commercial            investment
# 16           applications        information                hirsch
# 17                    pnl               0400                sector
# 18              equipment               site                  jeff
# 19               national                web               version
# 20                    doe             people                  doe2
# 21              available               corp                  heat
# 22            information               vice                    1e
# 23                   size                 st           temperature
# 24                   0500          president                  0400
# 25                 street                862                   ext
# 26                   0700                 ma                 suite
# 27                   find              voice              engineer
# 28                    web              suite                 phone
# 29               engineer                usa               program
# ..                    ...                ...                   ...
# 170               weather         energyplus                 jones
# 171  whiteboxtechnologies           workshop           information
# 172                   joe         openstudio              intended
# 173               climate      designbuilder           christopher
# 174                   epw           training               ontario
# 175                 huang         eventbrite               thermal
# 176                 white  bigladdersoftware                   eng
# 177             locations           software                 power
# 178                 suite             ladder         communication
# 179               yjhuang          workshops               toronto
# 180                 ibpsa         energyplus               weather
# 181                   usa         openstudio                   joe
# 182                  news           workshop  whiteboxtechnologies
# 183            newsletter  bigladdersoftware                   doe
# 184                latest           training                 huang
# 185               updates      designbuilder                   box
# 186             community           controls                 white
# 187                 issue             denver               yjhuang
# 188              training           software          technologies
# 189                manage          workshops              february
# 190              research            tickets              lighting
# 191               control         eventbrite              linkedin
# 192            experience               tool                 value
# 193          optimization               cost                  leed
# 194           engineering       optimization                   cgi
# 195               systems            company              listinfo
# 196                 tools            webinar                 wrote
# 197           performance           linkedin         designbuilder
# 198                 apply               free                annual
# 199              modeling             create                    pe
#
#                 6                        7                       8  \
# 0        software                   source                research
# 1      experience                   hourly                 project
# 2         looking                    wrote                    0700
# 3            0600                     good                   phone
# 4          better                     0700                    good
# 5           tools                       1e                     jun
# 6              04               interested                 program
# 7             web               references              experience
# 8         program                  looking               available
# 9         version                  program               analytics
# 10            doe                     john                powerdoe
# 11        program                  systems                    0500
# 12     energyplus                     free                modeling
# 13           user                  private             temperature
# 14    engineering                 modeling                    hvac
# 15          input                     high                   input
# 16        systems                     0800               including
# 17    information                     heat                 project
# 18        version                      see               interface
# 19      interface               interested                    find
# 20          loads                 research                software
# 21         office                   ashrae                 program
# 22          power              information                programs
# 23      equipment                    group                    size
# 24             05              engineering              experience
# 25           hvac                  systems                     jun
# 26          wrote               university               available
# 27         ashrae                    based                  people
# 28     references                     hvac                     web
# 29             il                 question                engineer
# ..            ...                      ...                     ...
# 170  gototraining                      jim                   water
# 171      attendee                   dirkes                 cooling
# 172      register  buildingperformanceteam                    heat
# 173       webinar                 linkedin                     air
# 174       network                      cgi                  source
# 175   performance                 listinfo                     hot
# 176          live                     8653                 version
# 177     organized                       ii                    cost
# 178   grasshopper                      ceo                   chris
# 179        series                     1631                electric
# 180           510                 research  buildingsimulation2017
# 181         chris              engineering                   ibpsa
# 182         solar               university                   image
# 183       glazing               experience              conference
# 184         wrote              environment            registration
# 185            uk               technology                 twitter
# 186         green                  systems                facebook
# 187         glass                institute                   click
# 188          best                    based                linkedin
# 189         range              information                     usa
# 190          wind                  webinar              conference
# 191          rain                 register                   users
# 192        driven              performance                modeling
# 193           joe                   denver                simbuild
# 194      stations                 attendee           presentations
# 195     different              gotowebinar                  ashrae
# 196         speed                    green             conferences
# 197         urban             presentation                 program
# 198            uk                  network             performance
# 199         field                   school                      3a
#
#                 9  year
# 0     information  1999
# 1      interested  1999
# 2         looking  1999
# 3            site  1999
# 4             web  1999
# 5            good  1999
# 6            bill  1999
# 7       available  1999
# 8           tools  1999
# 9           phone  1999
# 10           mark  2000
# 11           case  2000
# 12          group  2000
# 13           0600  2000
# 14     commercial  2000
# 15            jun  2000
# 16        program  2000
# 17             go  2000
# 18           find  2000
# 19     experience  2000
# 20           load  2001
# 21       question  2001
# 22        systems  2001
# 23           0500  2001
# 24           hvac  2001
# 25        program  2001
# 26         source  2001
# 27     interested  2001
# 28        project  2001
# 29    temperature  2001
# ..            ...   ...
# 170      standard  2016
# 171        ashrae  2016
# 172        review  2016
# 173        public  2016
# 174         jason  2016
# 175         chair  2016
# 176   residential  2016
# 177            ny  2016
# 178      appendix  2016
# 179  requirements  2016
# 180        ashrae  2017
# 181    conference  2017
# 182   performance  2017
# 183   conferences  2017
# 184          leed  2017
# 185      modeling  2017
# 186        review  2017
# 187      standard  2017
# 188     available  2017
# 189   residential  2017
# 190       heating  2018
# 191        source  2018
# 192       project  2018
# 193       thermal  2018
# 194       systems  2018
# 195           air  2018
# 196          case  2018
# 197        ashrae  2018
# 198   residential  2018
# 199       example  2018
#
# [200 rows x 11 columns]

# %%
all_topics_df_melted = all_topics_df.melt(id_vars='year')

# %%
all_topics_df_melted.head()
# Out:
#    year variable    value
# 0  1999        0      doe
# 1  1999        0       1e
# 2  1999        0     user
# 3  1999        0  version
# 4  1999        0     0400

# %%
all_topics_df_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
# year        2000 non-null int64
# variable    2000 non-null object
# value       2000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 46.9+ KB

# %%
wordfreq = all_topics_df_melted.value.value_counts()

# %%
wordfreq.head(40)
# Out:
# leed           24
# energyplus     20
# cooling        20
# ashrae         18
# heat           18
# weather        18
# equest         17
# performance    16
# software       16
# air            15
# baseline       15
# doe            15
# modeling       15
# experience     15
# source         14
# program        14
# fan            14
# ibpsa          14
# available      13
# water          13
# engineering    13
# information    12
# web            12
# systems        12
# heating        12
# usa            12
# thermal        12
# temperature    11
# doe2           11
# 0500           11
# training       10
# conference     10
# university     10
# joe            10
# load           10
# yahoo           9
# jeff            9
# research        9
# version         9
# interested      8
# Name: value, dtype: int64

# %%
wordfreq
# Out:
# leed                   24
# energyplus             20
# cooling                20
# ashrae                 18
# heat                   18
# weather                18
# equest                 17
# performance            16
# software               16
# air                    15
# baseline               15
# doe                    15
# modeling               15
# experience             15
# source                 14
# program                14
# fan                    14
# ibpsa                  14
# available              13
# water                  13
# engineering            13
# information            12
# web                    12
# systems                12
# heating                12
# usa                    12
# thermal                12
# temperature            11
# doe2                   11
# 0500                   11
#                        ..
# qm                      1
# espr                    1
# recommendations         1
# dcmit_esiyok            1
# qc                      1
# lexington               1
# bat                     1
# eskewdumezripple        1
# prosoco                 1
# click                   1
# 01                      1
# cop                     1
# 361                     1
# javed                   1
# energyplus_support      1
# vrf                     1
# job                     1
# efficiency              1
# 0af59bbb65              1
# exam                    1
# jta                     1
# sheffer                 1
# volume                  1
# outside                 1
# mud                     1
# dormitory               1
# fenestration            1
# naturalintelligence     1
# 07                      1
# natural                 1
# Name: value, Length: 831, dtype: int64

# %%
wordfreq.to_csv("word_frequency.csv")
